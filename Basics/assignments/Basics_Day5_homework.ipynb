# %% [markdown]
# # Python Basics - Day 5 Homework
#
# This homework aligns with Day 5 topics:
# 1. Tuples + unpacking
# 2. Sets: uniqueness + membership
# 3. Dictionaries fundamentals
# 4. Dictionary iteration + counting pattern

# %% [markdown]
# ### 🤖 Autograder Integration
#
# This assignment is graded automatically by the **Global Autograder**. Please follow these rules carefully:
#
# - All solution code **must live in this notebook** and run without errors.
# - The autograder converts this notebook to `basics_day5.py` and grades it against `criteria.json`.
# - **Outputs must exactly match** the canonical strings in `criteria.json` (ordering, spelling, spacing, casing).
# - Use **deterministic** `print()` statements only (no randomness, timestamps, or interactive input during grading).
# - Keep formatting precise.
# - Do **not** read/write files outside this assignment directory.
# - **Do not rename or move** this notebook or the config files (`criteria.json`, `setup.json`, `feedback.json`).
# - Run all cells before submitting to catch errors early.
#
# A reference output block is provided near the end so you can self-check your results before submission.

# %% [markdown]
# ---

# %% [markdown]
# ## Hour 17 - Tuples + unpacking

# %%
# Exercise 1.1 — Tuples + unpacking (TODO)
# TODO: Create a tuple named `coordinates` with values (12, 34).
# TODO: Unpack it into `x_value` and `y_value`.
# TODO: Create a tuple named `weekdays` with five weekday names.
# TODO: Slice the first three days into `first_three_days`.
# TODO: Create `roles` as ('mentor', 'student') and then create `updated_roles` by adding 'reviewer'.
# TODO: Print the five required lines exactly as shown in the canonical output block.
coordinates: tuple[int, int] = ()
x_value = None
y_value = None
weekdays: tuple[str, ...] = ()
first_three_days: tuple[str, ...] = ()
roles: tuple[str, ...] = ()
updated_roles: tuple[str, ...] = ()

# %% [markdown]
# ---

# %% [markdown]
# ## Hour 18 - Sets: uniqueness + membership

# %%
# Exercise 2.1 — Sets uniqueness + membership (TODO)
# TODO: Use the list below, convert it to a set, and compute unique values.
# TODO: Print raw count, unique count, two membership checks, and sorted unique colors.
# TODO: Match the five output lines in the canonical output block exactly.
colors: list[str] = ['red', 'blue', 'green', 'blue', 'red', 'violet', 'green']
unique_colors: set[str] = set()
sorted_unique_colors: list[str] = []

# %% [markdown]
# ---

# %% [markdown]
# ## Hour 19 - Dictionaries fundamentals

# %%
# Exercise 3.1 — Dictionaries fundamentals (TODO)
# TODO: Create a dictionary named `learner_profile` with keys: name, role, city.
# TODO: Use key access to print name and role.
# TODO: Update city to 'Lagos'.
# TODO: Print sorted keys and a membership check for key 'email'.
# TODO: Match the canonical five output lines exactly.
learner_profile: dict[str, str] = {}

# %% [markdown]
# ---

# %% [markdown]
# ## Hour 20 - Dictionary iteration + counting pattern

# %%
# Exercise 4.1 — Dictionary iteration + counting pattern (TODO)
# TODO: Count each word in the list below using a dictionary.
# TODO: Use the common counting pattern with if/else or dict.get().
# TODO: Build a deterministic summary string sorted by word:
#       data=2, fun=1, python=3, rocks=2
# TODO: Print the five required lines from the canonical output block.
words: list[str] = ['python', 'data', 'python', 'rocks', 'data', 'python', 'rocks', 'fun']
word_counts: dict[str, int] = {}
counts_summary = ''

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## 🤖 Autograder Helper — Canonical Output Script
#
# The script below shows the **exact expected outputs** that the autograder checks.
# Your notebook code in the exercises above must produce output lines that match these canonical strings exactly (same labels, same values, same formatting).
#
# ```python
# # Canonical script for Day 5 grading by autograder (basics_day5.py)
# def main():
#     print("Coordinates tuple: (12, 34)")
#     print("X value: 12")
#     print("Y value: 34")
#     print("First three days: ('Mon', 'Tue', 'Wed')")
#     print("Updated roles: ('mentor', 'student', 'reviewer')")
#
#     print("Raw item count: 7")
#     print("Unique item count: 4")
#     print("Is 'blue' present: True")
#     print("Is 'yellow' present: False")
#     print("Unique sorted colors: ['blue', 'green', 'red', 'violet']")
#
#     print("Profile keys: ['city', 'name', 'role']")
#     print("Learner name: Nia")
#     print("Learner role: analyst")
#     print("Updated city: Lagos")
#     print("Has 'email' key: False")
#
#     print("Total words: 8")
#     print("Unique words: 4")
#     print("Count for 'python': 3")
#     print("Count for 'data': 2")
#     print("Word counts: data=2, fun=1, python=3, rocks=2")
#
# if __name__ == '__main__':
#     main()
# ```
#
# ### Local testing steps
#
# ```bash
# python -m pip install nbconvert
# jupyter nbconvert --to script ../Basics_Day5_homework.ipynb --output basics_day5 --output-dir .
# python basics_day5.py
# ```
#
# Compare the output to the canonical strings in `criteria.json`.
