# %% [markdown]
# # Python Basics - Day 3 Homework
#
# **Topics Covered:**
# - Hour 9: Comparisons + boolean logic
# - Hour 10: String formatting with f-strings
# - Hour 11: Working with text — split() and join()
# - Hour 12: Debugging habits — read errors, inspect values, fix methodically
#
# **Instructions:**
# - Complete all exercises in order
# - Write your code in the provided cells
# - Test your code by running the cell (Shift+Enter)
# - Use modern Python practices: f-strings, type hints, and descriptive variable names
# - Follow PEP 8 style guidelines
# - Add comments to explain your reasoning where appropriate
#
# **Submission:**
# - Save your completed notebook
# - Ensure all cells run without errors
# - Submit according to your instructor's guidelines
#
# ---
#
# ### 🤖 Autograder Integration
#
# This assignment is graded automatically by the **Global Autograder**. Please follow these rules carefully:
#
# - **All solution code MUST be present and runnable** in this notebook.
# - The autograder converts this notebook to `day3.py` and grades it against `criteria.json`.
# - **Outputs must exactly match** the canonical strings in `criteria.json` for all graded exercises.
#   - Example: `Bracket: teen`, `Bill: $48.50`
#   - No extra whitespace, punctuation, or incorrect ordering.
# - **Numeric outputs** must use the requested precision (for example, money should use 2 decimal places).
# - All `print()` statements must be **deterministic** (no randomness, no live timestamps, no interactive input during grading).
# - The notebook must **NOT** read or write files outside the assignment directory.
# - **Run all cells** and ensure no errors before submission.
# - **Do not rename** this notebook file, move it to a different directory, or alter the config files (`criteria.json`, `setup.json`, `feedback.json`). Doing so will break the autograder workflow.
#
# A helper cell at the end of this notebook provides a canonical script (`day3.py`) showing the exact expected outputs for each graded section. Use it to preview and debug before submission.

# %% [markdown]
# ---
# ## Part 1: Comparisons + Boolean Logic (25 points)
#
# ### Exercise 1.1: Eligibility Checker (10 points — graded)
#
# Use the values below to build a small eligibility checker:
#
# - `age = 17`
# - `has_membership = True`
#
# Your program must determine:
#
# 1. Which age bracket the learner belongs to (`child`, `teen`, or `adult`)
# 2. Whether the learner can join the teen workshop (`13 <= age <= 17`)
# 3. Whether the learner needs a parent form (only learners under 16 need one)
# 4. Whether the learner's membership is active
#
# **Required output format (must match exactly):**
# ```
# Age: 17
# Bracket: teen
# Has membership: True
# Can join teen workshop: True
# Needs parent form: False
# ```
#
# **Teaching reminder:** Use comparison operators carefully at the boundaries. Off-by-one mistakes are very common here.

# %%
# Exercise 1.1 — Eligibility checker
age: int = 17
has_membership: bool = True

# TODO: Determine the age bracket

# TODO: Determine whether the learner can join the teen workshop

# TODO: Determine whether the learner needs a parent form

# TODO: Print the required lines exactly as shown in the prompt

# %% [markdown]
# ### Exercise 1.2: Boundary Value Practice (8 points)
#
# Using the ages `12`, `13`, `17`, and `18`, print whether each age is inside the teen range.
#
# - Use a loop
# - Use a boolean expression
# - Print each result with a clear label such as `Age 12 in teen range: False`
#
# This exercise is about **testing the edges** of a condition, not just the middle values.

# %%
# Exercise 1.2 — Boundary value practice
ages_to_test: list[int] = [12, 13, 17, 18]

# TODO: Loop through the ages and print whether each one is in the teen range

# %% [markdown]
# ### Exercise 1.3: Boolean Logic Story Problems (7 points)
#
# Create three small boolean expressions using the variables below:
#
# - `is_weekend = True`
# - `finished_homework = True`
# - `has_laptop = False`
#
# Write and print expressions that answer these questions:
#
# 1. Can the student relax? (weekend **and** homework finished)
# 2. Can the student code anywhere? (has laptop **or** finished homework)
# 3. Does the student still need equipment? (**not** has_laptop)
#
# Add a short comment beside each expression explaining *why* the result makes sense.

# %%
# Exercise 1.3 — Boolean logic story problems
is_weekend: bool = True
finished_homework: bool = True
has_laptop: bool = False

# TODO: Create and print the three boolean expressions

# %% [markdown]
# ---
# ## Part 2: String Formatting with f-Strings (25 points)
#
# ### Exercise 2.1: Tip Summary Formatter (12 points — graded)
#
# Use f-strings to print a clear, readable summary for these values:
#
# - `bill = 48.50`
# - `tip_rate = 18`
# - `people = 2`
#
# Calculate the tip amount, total bill, and cost per person.
#
# **Required output format (must match exactly):**
# ```
# Bill: $48.50
# Tip (18%): $8.73
# Total: $57.23
# Per person (2): $28.61
# ```
#
# **Important:** Use f-strings for every output line and format money with exactly two decimal places.

# %%
# Exercise 2.1 — Tip summary formatter
bill: float = 48.50
tip_rate: int = 18
people: int = 2

# TODO: Calculate the tip amount

# TODO: Calculate the total

# TODO: Calculate the cost per person

# TODO: Print each line using f-strings and the required formatting

# %% [markdown]
# ### Exercise 2.2: Aligned Progress Report (8 points)
#
# Build a tiny progress report using width specifiers in f-strings.
#
# Use:
# - `name = "Mina"`
# - `lessons_completed = 7`
# - `target = 10`
# - `average_score = 93.456`
#
# Print a neat report where:
# - labels line up on the left,
# - the score is shown with **2 decimal places**, and
# - the completion line includes both the completed value and the target.
#
# This exercise is not graded by the autograder, so focus on readability and clean formatting.

# %%
# Exercise 2.2 — Aligned progress report
name: str = "Mina"
lessons_completed: int = 7
target: int = 10
average_score: float = 93.456

# TODO: Print a tidy progress report using f-string width/alignment specifiers

# %% [markdown]
# ### Exercise 2.3: From Concatenation to f-Strings (5 points)
#
# Take the information below and print a debugging status message in **two ways**:
#
# - first with string concatenation,
# - then with an f-string.
#
# Use:
# - `bug_name = "IndexError"`
# - `line_number = 12`
# - `status = "fixed"`
#
# After printing both versions, add a short comment explaining why the f-string version is easier to read and maintain.

# %%
# Exercise 2.3 — From concatenation to f-strings
bug_name: str = "IndexError"
line_number: int = 12
status: str = "fixed"

# TODO: Print one message with concatenation

# TODO: Print the same message with an f-string

# TODO: Add a comment explaining which style is clearer and why

# %% [markdown]
# ---
# ## Part 3: Working with Text — split() and join() (25 points)
#
# ### Exercise 3.1: Sentence Stats and Rebuild (12 points — graded)
#
# Start with the sentence below:
#
# `sentence = "Python   makes   debugging   easier"`
#
# Use `.split()` and `.join()` to produce the following information:
#
# 1. Word count
# 2. Longest word
# 3. A pipe-separated version of the words
# 4. A comma-separated version of the words
#
# **Required output format (must match exactly):**
# ```
# Word count: 4
# Longest word: debugging
# Pipe version: Python | makes | debugging | easier
# CSV version: Python,makes,debugging,easier
# ```
#
# **Hint:** Calling `.split()` with no arguments is helpful here because it treats repeated spaces as one separator.

# %%
# Exercise 3.1 — Sentence stats and rebuild
sentence: str = "Python   makes   debugging   easier"

# TODO: Split the sentence into words

# TODO: Print the word count

# TODO: Find and print the longest word

# TODO: Join the words with pipes and commas, then print the results

# %% [markdown]
# ### Exercise 3.2: Clean a Comma List (8 points)
#
# Given the text below, create a clean list of names:
#
# `raw_names = "Ada, Grace,  Linus,Guido"`
#
# Tasks:
# 1. Split on commas
# 2. Strip extra spaces from each item
# 3. Print the cleaned list
# 4. Join the cleaned names with `" / "`
#
# This exercise is great practice for preparing messy text before you analyze or display it.

# %%
# Exercise 3.2 — Clean a comma list
raw_names: str = "Ada, Grace,  Linus,Guido"

# TODO: Split the names

# TODO: Strip whitespace from each name

# TODO: Print the cleaned list and a slash-joined version

# %% [markdown]
# ### Exercise 3.3: Username Builder from Full Name (5 points)
#
# Use the full name `"Maya Patel"` and create a username in this format:
#
# - first name in lowercase
# - underscore
# - last name in lowercase
#
# Then build a hashtag version of the same name by splitting the name into words and joining them with no spaces after a `#` symbol.
#
# **Example output:**
# ```
# Username: maya_patel
# Hashtag: #MayaPatel
# ```

# %%
# Exercise 3.3 — Username builder from full name
full_name: str = "Maya Patel"

# TODO: Split the full name into pieces

# TODO: Build and print the username

# TODO: Build and print the hashtag version

# %% [markdown]
# ---
# ## Part 4: Debugging Habits (25 points)
#
# ### Exercise 4.1: Print-Debug Checkpoint (10 points — graded)
#
# Use the values below to practice **inspecting values before changing code**:
#
# - `raw_value = "17"`
# - `supplies = ["pen", "notebook", "eraser"]`
# - `index_to_check = 5`
#
# Your program must:
#
# 1. Print the raw value
# 2. Print the type name before conversion
# 3. Convert the value to an integer and print the new type name
# 4. Check whether `index_to_check` is a safe index for the list **before** trying to access it
# 5. Print one debugging reminder sentence
#
# **Required output format (must match exactly):**
# ```
# Debug value: 17
# Debug type before fix: str
# Debug type after fix: int
# Index 5 exists: False
# Debug rule: Change one thing at a time
# ```
#
# This exercise models the kind of quick checks that help you avoid `TypeError` and `IndexError`.

# %%
# Exercise 4.1 — Print-debug checkpoint
raw_value: str = "17"
supplies: list[str] = ["pen", "notebook", "eraser"]
index_to_check: int = 5

# TODO: Print the raw value

# TODO: Print the type name before conversion

# TODO: Convert the value and print the type name after conversion

# TODO: Check whether the index is safe before accessing the list

# TODO: Print the debugging reminder sentence

# %% [markdown]
# ### Exercise 4.2: Read the Bug, Then Fix the Bug (8 points)
#
# Below is a broken script. Copy it into the code cell and fix it step by step.
#
# ```python
# name = "Kai"
# score = "95"
# print(f"Student: {Name}")
# print(score + 5)
# ```
#
# Tasks:
# 1. Identify the first error you would expect
# 2. Fix the variable-name problem
# 3. Fix the type problem so the final score math works
# 4. Add one `print()` statement you would use while debugging, then remove it once you are done
#
# Add comments that explain **what went wrong** and **how you knew what to fix**.

# %%
# Exercise 4.2 — Read the bug, then fix the bug
# TODO: Copy the broken script here and fix it step by step

# %% [markdown]
# ### Exercise 4.3: Tiny Traceback Reflection (7 points)
#
# Write a short explanation in code comments or `print()` statements answering these questions:
#
# 1. Why should you read the **bottom** of a traceback carefully?
# 2. Why is it risky to change many lines of code at once while debugging?
# 3. Why is a small test input useful when you are trying to reproduce a bug?
#
# This is a thinking exercise: focus on the debugging process, not just the fix.

# %%
# Exercise 4.3 — Tiny traceback reflection
# TODO: Answer the three reflection prompts in comments or short print() statements

# %% [markdown]
# ---
# ## Reflection Questions (10 points)
#
# Answer these questions in the markdown cell below:
#
# 1. Why is `13 <= age <= 17` often clearer than writing two separate comparisons with `and`?
#
# 2. What common formatting mistake happens when you forget the `f` in an f-string?
#
# 3. Why is `.split()` with no argument usually better than `.split(" ")` when a sentence may contain irregular spacing?
#
# 4. When debugging, what does printing both a value and its type help you discover?
#
# 5. Describe a time when changing one small thing at a time would be safer than rewriting the whole program at once.

# %% [markdown]
# ### Your Answers:
#
# 1.
#
# 2.
#
# 3.
#
# 4.
#
# 5.

# %% [markdown]
# ---
# ## Submission Checklist
#
# Before submitting, verify:
#
# - [ ] All code cells run without errors
# - [ ] All exercises are complete
# - [ ] Code follows PEP 8 style guidelines
# - [ ] Variables have descriptive names
# - [ ] F-strings are used where requested
# - [ ] Type hints are included where requested
# - [ ] Comments explain your reasoning
# - [ ] Reflection questions are answered
# - [ ] Output is clear and well-formatted
#
# **Total Points: 110 (100 base + 10 reflection)**
#
# Great work on completing Day 3! 🎉
#
# ### Autograder Checklist
#
# - [ ] Outputs match canonical strings in `criteria.json` exactly
# - [ ] Numeric values use correct precision (see format specifiers)
# - [ ] No extra whitespace or punctuation in output lines
# - [ ] All outputs are deterministic (no randomness, no live date/time)
# - [ ] Notebook has not been renamed or moved from its original location

# %% [markdown]
# ---
# ## 🤖 Autograder Helper — Canonical Output Script
#
# The script below shows the **exact expected outputs** that the autograder checks.
# Your notebook code in the exercises above must produce output lines that match these canonical strings exactly (same labels, same values, same formatting).
#
# ```python
# # Canonical script for Day 3 grading by autograder (day3.py)
# def main():
#     # Part 1: Comparisons and boolean logic (Exercise 1.1)
#     print("Age: 17")
#     print("Bracket: teen")
#     print("Has membership: True")
#     print("Can join teen workshop: True")
#     print("Needs parent form: False")
#
#     # Part 2: F-string formatting (Exercise 2.1)
#     print("Bill: $48.50")
#     print("Tip (18%): $8.73")
#     print("Total: $57.23")
#     print("Per person (2): $28.61")
#
#     # Part 3: split() / join() (Exercise 3.1)
#     print("Word count: 4")
#     print("Longest word: debugging")
#     print("Pipe version: Python | makes | debugging | easier")
#     print("CSV version: Python,makes,debugging,easier")
#
#     # Part 4: Debugging habits (Exercise 4.1)
#     print("Debug value: 17")
#     print("Debug type before fix: str")
#     print("Debug type after fix: int")
#     print("Index 5 exists: False")
#     print("Debug rule: Change one thing at a time")
#
# if __name__ == "__main__":
#     main()
# ```
#
# ### Local testing steps
#
# From the repository root:
#
# ```bash
# cd Basics/assignments/Basics_Day3_homework/
# python -m pip install nbconvert
# jupyter nbconvert --to script ../Basics_Day3_homework.ipynb --output day3 --output-dir .
# python day3.py
# ```
#
# Compare the output to the canonical strings in `criteria.json`.
