# %% [markdown]
# # Python Basics - Day 4 Homework
#
# This homework aligns with Day 4 topics:
# 1. Lists fundamentals
# 2. Iterating lists with for-loops
# 3. Nested lists (table-like data)
# 4. Checkpoint: Lists + string handling

# %% [markdown]
# ### 🤖 Autograder Integration
#
# This assignment is graded automatically by the **Global Autograder**. Please follow these rules carefully:
#
# - All solution code **must live in this notebook** and run without errors.
# - The autograder converts this notebook to `day4.py` and grades it against `criteria.json`.
# - **Outputs must exactly match** the canonical strings in `criteria.json` (ordering, spelling, spacing, casing).
# - Use **deterministic** `print()` statements only (no randomness, timestamps, or interactive input during grading).
# - Keep numeric formatting precise (for example, two decimals for money when asked).
# - Do **not** read/write files outside this assignment directory.
# - **Do not rename or move** this notebook or the config files (`criteria.json`, `setup.json`, `feedback.json`).
# - Run all cells before submitting to catch errors early.
#
# A reference output block is provided near the end so you can self-check your results before submission.

# %% [markdown]
# ---

# %% [markdown]
# ## Hour 13 - Lists fundamentals

# %%
# Exercise 1.1 — Lists fundamentals (TODO)
# TODO: Create a list named `roster` with the learners: Ava, Ben, Cara, Dev, Eli.
# TODO: Print the required details exactly as shown in the reference output block:
#   - Roster size
#   - First learner
#   - Last learner
#   - Middle learners slice (the middle three)
#   - Updated roster after changing 'Cara' to 'Cora' and appending 'Finn'
# Replace the starter list below and add the print statements.
roster: list[str] = []

# %% [markdown]
# ---

# %% [markdown]
# ## Hour 14 - Iterating lists with for-loops

# %%
# Exercise 2.1 — Iterating lists with for-loops (TODO)
# TODO: Use a list of names and compute the aggregate stats listed in the reference block.
# Requirements:
#   - Use a running total accumulator for character counts
#   - Track the longest name using len()
#   - Build a filtered list of names starting with 'C'
#   - Build an uppercase version of the `roster_for_uppercase` list
#   - Print the five lines shown in the reference output block
names: list[str] = ["Anna", "Christopher", "Maya", "Leo", "Chloe"]
roster_for_uppercase: list[str] = ["Anna", "Chris", "Maya", "Leo"]
total = 0
longest_name = ""
starts_with_c: list[str] = []
uppercase_roster: list[str] = []
# TODO: Write your loops and calculations here

# %% [markdown]
# ---

# %% [markdown]
# ## Hour 15 - Nested lists (table-like data)

# %%
# Exercise 3.1 — Nested lists (TODO)
# TODO: Represent seats as nested lists (rows of strings).
# Build the flattened list and print the five lines in the reference output block.
seats: list[list[str]] = []
flattened: list[str] = []
# TODO: Add rows, flatten, and print the required values

# %% [markdown]
# ---

# %% [markdown]
# ## Hour 16 - Checkpoint 2: Lists + string handling

# %%
# Exercise 4.1 — Checkpoint integration (TODO)
# TODO: Split the raw tag string, clean whitespace, join with '-' for a slug,
# and print the five lines in the reference output block.
raw_tags = "python, lists, loops, strings"
clean_tags: list[str] = []
slug = ""
# TODO: Implement the cleaning, membership check, and prints

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## 🤖 Autograder Helper — Canonical Output Script
#
# The script below shows the **exact expected outputs** that the autograder checks.
# Your notebook code in the exercises above must produce output lines that match these canonical strings exactly (same labels, same values, same formatting).
#
# ```python
# # Canonical script for Day 4 grading by autograder (day4.py)
# def main():
#     print("Roster size: 5")
#     print("First learner: Ava")
#     print("Last learner: Eli")
#     print("Middle learners: ['Ben', 'Cara', 'Dev']")
#     print("Updated roster: ['Ava', 'Ben', 'Cora', 'Dev', 'Eli', 'Finn']")
#
#     print("Name count total: 27")
#     print("Longest name: Christopher")
#     print("Average length: 5.40")
#     print("Starts with C: ['Christopher', 'Chloe']")
#     print("Uppercase roster: ['ANNA', 'CHRIS', 'MAYA', 'LEO']")
#
#     print("Rows: 3")
#     print("Columns per row: 3")
#     print("Seat at row 2 col 3: B3")
#     print("Flattened seats: A1,A2,A3,B1,B2,B3,C1,C2,C3")
#     print("Total seats: 9")
#
#     print("Raw tags: python, lists, loops, strings")
#     print("Clean tags: ['python', 'lists', 'loops', 'strings']")
#     print("Tag count: 4")
#     print("Slug: python-lists-loops-strings")
#     print("Contains 'loops': True")
#
# if __name__ == "__main__":
#     main()
# ```
#
# ### Local testing steps
#
# ```bash
# python -m pip install nbconvert
# jupyter nbconvert --to script Basics_Day4_homework.ipynb --output day4.py
# python day4.py
# ```
#
# Compare the output to the canonical strings in `criteria.json`.
