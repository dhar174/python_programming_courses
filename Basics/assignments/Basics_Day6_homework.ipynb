# %% [markdown]
# # Python Basics - Day 6 Homework
#
# **Runbook alignment (Day 6, Hours 21-24):**
# - Hour 21: Choosing the right structure
# - Hour 22: Data-structure drill circuit (guided practice)
# - Hour 23: Mini-project: In-memory tracker
# - Hour 24: Checkpoint 3: Data structures assessment
#
# Use only Basics-scope concepts from class. Keep output clear and deterministic.

# %% [markdown]
# ### Autograder Integration Requirements
#
# This assignment is graded automatically.
#
# - Put your complete runnable solutions in this notebook.
# - Your notebook will be converted to `day6.py` and checked against `criteria.json`.
# - Output strings must match expected labels and formatting exactly.
# - Keep numeric/string formatting precise when requested.
# - Do not use randomness, live date/time, or external files.
# - Use safe dictionary lookups (`in` checks or `dict.get`) to avoid `KeyError`.

# %% [markdown]
# ---
# ## Part 1: Hour 21 - Choosing the right structure (25 points)

# %% [markdown]
# ### Exercise 1.1: Structure Selection Matrix (12 points - graded)
#
# For each task, print which structure fits best (`list`, `set`, `dict`, or `tuple`) and a one-line reason.
#
# Tasks to classify:
# 1. Keep insertion order and allow duplicates.
# 2. Fast unique membership checks.
# 3. Lookup phone by contact name.
# 4. Store one fixed coordinate pair.
#
# Use explicit labels in your output so results are easy to read.

# %%
# Exercise 1.1 - Structure selection matrix

# TODO: Print best structure for each task with a short reason.
# Example label style:
# print("Task 1 best structure: list")
# print("Reason: preserves order and duplicates")

# %% [markdown]
# ### Exercise 1.2: Refactor Challenge (13 points - graded)
#
# Start from a duplicate-heavy list and refactor to better structures.
#
# 1. Use `list` input: `names = ["Ava", "Ben", "Ava", "Cara", "Ben", "Ava"]`
# 2. Produce unique names with a `set`.
# 3. Produce frequency counts with a `dict`.
# 4. Print one tradeoff sentence explaining when `set` is better and when `list` is better.

# %%
# Exercise 1.2 - Refactor list to set/dict
names: list[str] = ["Ava", "Ben", "Ava", "Cara", "Ben", "Ava"]

# TODO: Build a set of unique names.
# TODO: Build a dict count map.
# TODO: Print deterministic summaries (sort where needed).
# TODO: Print one tradeoff statement.

# %% [markdown]
# ---
# ## Part 2: Hour 22 - Data-structure drill circuit (30 points)

# %% [markdown]
# ### Exercise 2.1: Station A - List Filter (8 points - graded)
#
# Given `numbers = [3, 12, 7, 18, 10, 27]`, print a list containing only values greater than 10.

# %%
# Exercise 2.1 - List filter
numbers: list[int] = [3, 12, 7, 18, 10, 27]

# TODO: Filter values > 10.
# TODO: Print with label: "Filtered > 10: ..."

# %% [markdown]
# ### Exercise 2.2: Station B - Unique Emails with Set (8 points - graded)
#
# Given duplicated emails, create a unique sorted list for display.
#
# `emails = ["ana@example.com", "bob@example.com", "ana@example.com", "cy@example.com"]`

# %%
# Exercise 2.2 - Unique emails
emails: list[str] = [
    "ana@example.com",
    "bob@example.com",
    "ana@example.com",
    "cy@example.com",
]

# TODO: Convert to set for uniqueness.
# TODO: Sort for deterministic output.
# TODO: Print with label: "Unique emails: ..."

# %% [markdown]
# ### Exercise 2.3: Station C - Word Frequency with Dict (8 points - graded)
#
# Count each word in:
# `words = ["python", "data", "python", "loops", "data", "python"]`

# %%
# Exercise 2.3 - Word frequency
words: list[str] = ["python", "data", "python", "loops", "data", "python"]

# TODO: Build frequency dictionary using get() or in-check.
# TODO: Print with label: "Word counts: ..."

# %% [markdown]
# ### Exercise 2.4: Station D - Tuple Unpacking (6 points - graded)
#
# Use `point = (5, 9)`.
#
# 1. Unpack into `x_value`, `y_value`.
# 2. Print both values in one formatted line.

# %%
# Exercise 2.4 - Tuple unpacking
point: tuple[int, int] = (5, 9)

# TODO: Unpack tuple values.
# TODO: Print with label: "Coordinates unpacked: x=... y=..."

# %% [markdown]
# ---
# ## Part 3: Hour 23 - Mini-project: In-memory contact tracker (25 points)

# %% [markdown]
# ### Exercise 3.1: Build Core Features (15 points - graded)
#
# Create an in-memory contact tracker using **list + dict** records.
#
# Minimum required features:
# - Add contact (`name`, `phone`)
# - List contacts
# - Search by exact name
#
# Constraints:
# - No file I/O
# - Clear prompts/messages
# - Safe handling for missing names

# %%
# Exercise 3.1 - In-memory contact tracker core
contacts: list[dict[str, str]] = []

# TODO: Implement add_contact(name, phone).
# TODO: Implement list_contacts().
# TODO: Implement search_contact(name).
# TODO: Add at least two contacts and print deterministic results.

# %% [markdown]
# ### Exercise 3.2: Tracker Quality Checks (10 points)
#
# After implementing the core features, print confirmations that show:
# 1. A successful add operation.
# 2. A successful search.
# 3. A missing-name search that returns `Not found` (without crashing).
# 4. Current contact count.

# %%
# Exercise 3.2 - Tracker quality checks

# TODO: Print clear confirmations such as:
# "Added: Ava -> 555-0101"
# "Search Ava: 555-0101"
# "Search Zoe: Not found"
# "Contact count: 2"

# %% [markdown]
# ---
# ## Part 4: Hour 24 - Checkpoint 3: Data structures assessment (30 points)

# %% [markdown]
# ### Exercise 4.1: Simple Contacts (in-memory) (20 points - graded)
#
# Build a dict-based contact book:
#
# - Store contacts as `name -> phone`
# - Add at least 5 contacts
# - Search for one existing and one missing name
# - Print a clean contact list (sorted names)
# - Avoid `KeyError` by using safe access patterns

# %%
# Exercise 4.1 - Checkpoint 3 style assessment
contacts_map: dict[str, str] = {
    "Mia": "555-0130",
    "Liam": "555-0131",
    "Ava": "555-0132",
    "Zoe": "555-0133",
    "Eli": "555-0134",
}

# TODO: Lookup existing name and print result.
# TODO: Lookup missing name and print "Not found" safely.
# TODO: Print total contacts.
# TODO: Print sorted contact names in one line.
# TODO: Print one line that states which safe lookup strategy you used.

# %% [markdown]
# ### Exercise 4.2: Optional Extension (10 points)
#
# Add one extension:
# - Case-normalized search (`mia`, `MIA`, `Mia` all work), or
# - Partial match search (keyword contained in name)
#
# Keep this extension in Basics scope and explain your logic briefly in comments.

# %%
# Exercise 4.2 - Optional extension

# TODO: Implement one optional extension for searching.
# TODO: Show 2-3 example lookups.

# %% [markdown]
# ---
# ## Reflection Questions (10 points)
#
# Answer in the markdown cell below:
#
# 1. Why is `dict` a better fit than `list` for name-to-phone lookup?
# 2. When is `set` better than `list`?
# 3. What tradeoff did you observe when refactoring from list to set/dict?
# 4. How did you prevent `KeyError` in your checkpoint solution?
# 5. What improvement would you add to your contact tracker next?

# %% [markdown]
# ### Your Answers
#
# 1.
#
# 2.
#
# 3.
#
# 4.
#
# 5.

# %% [markdown]
# ---
# ## Submission Checklist
#
# Before submitting, verify:
#
# - [ ] All required code cells run without errors
# - [ ] Hour 21-24 tasks are completed
# - [ ] Structure choices are justified with readable reasoning
# - [ ] Tracker features include add/list/search
# - [ ] Missing-name lookups do not raise `KeyError`
# - [ ] Output labels are clear and deterministic
# - [ ] Reflection questions are answered
#
# ### Autograder Checklist
#
# - [ ] Output lines match canonical strings in `criteria.json`
# - [ ] No extra punctuation/whitespace in graded lines
# - [ ] Deterministic output only (no randomness, no live date/time)
# - [ ] Notebook file name and location are unchanged

# %% [markdown]
# ---
# ## Autograder Helper - Canonical Output Contract (`day6.py`)
#
# Your notebook implementation should be able to produce output lines consistent with the canonical contract below.
#
# ```python
# # Canonical script for Day 6 grading by autograder (day6.py)
# def main():
#     # Hour 21
#     print("Task: keep insertion order and allow duplicates -> list")
#     print("Task: fast unique membership checks -> set")
#     print("Task: lookup phone by name -> dict")
#     print("Tradeoff: set removes duplicates but loses original order")
#
#     # Hour 22
#     print("Filtered > 10: [12, 18, 27]")
#     print("Unique emails: ['ana@example.com', 'bob@example.com', 'cy@example.com']")
#     print("Word counts: {'python': 3, 'data': 2, 'loops': 1}")
#     print("Coordinates unpacked: x=5 y=9")
#
#     # Hour 23
#     print("Added: Ava -> 555-0101")
#     print("Added: Ben -> 555-0102")
#     print("Search Ava: 555-0101")
#     print("Search Zoe: Not found")
#     print("Contact count: 2")
#
#     # Hour 24
#     print("Lookup Mia: 555-0130")
#     print("Lookup Noah: Not found")
#     print("Total contacts: 5")
#     print("Contacts (sorted): Ava, Eli, Liam, Mia, Zoe")
#     print("Safe lookup used: dict.get")
#
# if __name__ == "__main__":
#     main()
# ```
#
# ### Local validation
#
# ```bash
# cd Basics/assignments/Basics_Day6_homework/
# python -m pip install nbconvert
# jupyter nbconvert --to script ../Basics_Day6_homework.ipynb --output day6 --output-dir .
# python day6.py
# ```
#
# Compare output to `criteria.json` expected strings.
