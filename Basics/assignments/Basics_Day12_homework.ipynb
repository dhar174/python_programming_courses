# %% [markdown]
# # Python Basics - Day 12 Homework
#
# **Runbook alignment (Day 12, Hours 45-48):**
# - Hour 45: Capstone kickoff requirements + scaffolding
# - Hour 46: Capstone build sprint
# - Hour 47: Capstone polish + demo readiness
# - Hour 48: Final assessment + certification-style review
#
# This notebook turns the organizer storyline from earlier Basics days into a small capstone. You will stay inside Python Basics scope while planning a menu-driven organizer, building core features, polishing the user experience, and reviewing the full course skill set before the final assessment.

# %% [markdown]
# ### Autograder Integration Requirements
#
# This assignment is graded automatically.
#
# - Put your complete runnable solution in this notebook.
# - The autograder may convert a submitted Day 12 notebook to `day12.py`.
# - Graded output must match the canonical strings in `criteria.json` exactly.
# - Keep all output deterministic: no randomness, no live date/time, and no hidden state.
# - Keep all file reads and writes inside this Day 12 assignment directory.
# - Do not change notebook filenames, config filenames, or folder names.
# - Avoid extra whitespace, extra punctuation, and extra print lines in graded output.
# - Run every cell before submitting and confirm that no errors appear.
# - Use only Python Basics concepts from the course: functions, one class, lists/dictionaries, JSON, `pathlib`, loops, conditionals, and targeted exception handling.
# - Do not use notebook magics such as `%%writefile` in your final graded code.

# %% [markdown]
# ---
# ## Part 1: Hour 45 - Capstone kickoff requirements + scaffolding
#
# ### Exercise 1.1: Build the organizer scaffold (graded)
#
# Create a Basics-friendly project skeleton for a small **Personal Organizer**.
#
# 1. Define a `Task` class with `title`, `priority`, and `done` attributes.
# 2. Add a method that returns either `"open"` or `"done"`.
# 3. Add a method that returns a display string like `"Study Python [high] open"`.
# 4. Use `pathlib` to point to `data/tasks.json` stored next to this notebook (even when running from another working directory).
# 5. Write `ensure_data_dir()`, `load_tasks()`, and `save_tasks(tasks)` helpers.
# 6. Keep `load_tasks()` safe: return an empty list if the file is missing or invalid.
#
# **Practice extension:** sketch a `menu_text()` function that lists the capstone commands you expect to support by the end of the day. You do not need a full interactive loop in the graded portion yet; the goal is a working scaffold first.

# %%
# Exercise 1.1 - capstone scaffold (Hour 45)
from pathlib import Path
import json

def get_base_dir() -> Path:
    """Return the Day 12 assignment folder for loading/saving data files.

    Prefer the directory containing this notebook or its converted script so
    paths stay anchored beside your submission even when executed from another
    working directory.
    """
    try:
        return Path(__file__).resolve().parent
    except NameError:
        cwd = Path.cwd()
        notebook_here = cwd / "Basics_Day12_homework.ipynb"
        repo_notebook = cwd / "Basics" / "assignments" / "Basics_Day12_homework.ipynb"
        if notebook_here.exists():
            return notebook_here.parent
        if repo_notebook.exists():
            return repo_notebook.parent
        return cwd


assignment_dir = get_base_dir()
data_dir = assignment_dir / "data"
data_file = data_dir / "tasks.json"


class Task:
    """Store one organizer task with a title, priority, and completion flag."""

    def __init__(self, title: str, priority: str, done: bool = False) -> None:
        # TODO: Save all three values on self.
        pass

    def status_label(self) -> str:
        # TODO: Return "done" when the task is complete, otherwise "open".
        pass

    def display(self) -> str:
        # TODO: Return a display string like "Study Python [high] open".
        pass


def task_to_dict(task: Task) -> dict[str, object]:
    # TODO: Convert one Task into a JSON-safe dictionary.
    pass


def dict_to_task(record: dict[str, object]) -> Task:
    # TODO: Build a Task object from one loaded dictionary.
    pass


def ensure_data_dir() -> None:
    # TODO: Create data_dir with mkdir(exist_ok=True).
    pass


def load_tasks() -> list[Task]:
    # TODO: Return [] if data_file does not exist.
    # TODO: Catch json.JSONDecodeError and return [] for a broken file.
    pass


def save_tasks(tasks: list[Task]) -> None:
    # TODO: Save a list of Task objects to data/tasks.json using json.dump(..., indent=2).
    pass

# %% [markdown]
# ---
# ## Part 2: Hour 46 - Capstone build sprint
#
# ### Exercise 2.1: Implement core organizer actions (graded)
#
# Use a list of `Task` objects to build the main work of the capstone.
#
# 1. Write `add_task(tasks, title, priority)`.
# 2. Write `list_tasks(tasks)` so it returns display strings with numbering.
# 3. Write `search_tasks(tasks, search_text)` so search is case-insensitive.
# 4. Write `complete_task(tasks, title)` so a matching task becomes done.
# 5. Use deterministic sample data for your graded preview.
# 6. Save the updated list back to JSON after the sprint preview.
#
# **Practice extension:** add one more Basics-friendly improvement such as `delete_task(...)`, sorted listing, or a confirmation message before a destructive action. Keep the graded output unchanged.

# %%
# Exercise 2.1 - build sprint (Hour 46)
starter_tasks: list[Task] = [
    Task("Study Python", "high", False),
    Task("Pay bills", "medium", False),
]


def add_task(tasks: list[Task], title: str, priority: str) -> None:
    # TODO: Append one new Task object to the list.
    pass


def list_tasks(tasks: list[Task]) -> list[str]:
    # TODO: Return numbered display lines such as "1. Pay bills [medium] open".
    pass


def search_tasks(tasks: list[Task], search_text: str) -> list[Task]:
    # TODO: Return all matching tasks using lowercase comparison.
    pass


def complete_task(tasks: list[Task], title: str) -> bool:
    # TODO: Mark the matching task as done and return True.
    # TODO: Return False when no title matches.
    pass


def hour46_preview() -> list[str]:
    # TODO: Build the five exact Hour 46 lines for the canonical output contract.
    pass

# %% [markdown]
# ---
# ## Part 3: Hour 47 - Capstone polish + demo readiness
#
# ### Exercise 3.1: Polish the organizer for a short demo (graded)
#
# Now make the project easier to use and easier to present.
#
# 1. Reject blank titles with a simple validation helper.
# 2. Build one help line that lists the supported commands.
# 3. Produce alphabetically sorted task titles for a cleaner demo.
# 4. Write a short demo flow string that explains what you will show live.
# 5. Keep the capstone inside Basics scope: readable prompts, small helpers, and no last-minute complexity.
#
# **Practice extension:** draft a short `README.md` outline or a `readme_lines()` helper that explains what the app does, how to run it, and where the JSON file lives. This extension is not graded, but it is excellent demo preparation.

# %%
# Exercise 3.1 - polish and demo readiness (Hour 47)
blank_titles: list[str] = ["", "   ", "Review notes"]
help_commands: list[str] = ["add", "list", "search", "complete", "save", "quit"]


def validate_title(title: str) -> bool:
    # TODO: Return False for blank or all-space titles.
    pass


def sorted_titles(tasks: list[Task]) -> list[str]:
    # TODO: Return task titles in alphabetical order.
    pass


def help_menu() -> str:
    # TODO: Return one comma-separated help line using help_commands.
    pass


def demo_flow() -> str:
    # TODO: Return the exact demo sequence for the Hour 47 output contract.
    pass


def readme_lines() -> list[str]:
    # Practice only: draft 3-4 short README lines for your project.
    pass

# %% [markdown]
# ---
# ## Part 4: Hour 48 - Final assessment + certification-style review
#
# ### Exercise 4.1: Build a final review summary (graded)
#
# Use the capstone to review the major Python Basics ideas from the course.
#
# 1. Summarize the data types you used.
# 2. Summarize the control-flow tools you used.
# 3. Summarize the file and persistence tools you used.
# 4. Summarize the error-handling tools you used.
# 5. Finish with one line that states your Basics capstone checklist is complete.
#
# **Practice extension:** before you run any code, predict the result of three short snippets that use slicing, `.get(...)`, `int(...)`, or `len(...)`. Then run them and check your reasoning. This mirrors the certification-style review from Hour 48.

# %%
# Exercise 4.1 - review summary (Hour 48)
review_topics: dict[str, str] = {
    "types": "",
    "flow": "",
    "files": "",
    "errors": "",
    "final": "",
}

prediction_snippets: list[str] = [
    'print(len("capstone"))',
    'print({"title": "Plan"}.get("priority", "medium"))',
    'print(int("7") + 1)',
]


def build_review_summary() -> dict[str, str]:
    # TODO: Fill in the exact review phrases needed for the output contract.
    return review_topics


def print_day12_contract() -> None:
    # TODO: When your notebook solution is complete, print all 20 canonical Day 12 lines.
    pass

# %% [markdown]
# ---
# ## Reflection Questions
#
# Use this space for short written responses.
#
# 1. What was your minimum viable product for the organizer?
# 2. Which function or helper became most useful during the build sprint?
# 3. How did JSON persistence make the capstone feel more realistic?
# 4. What would you show first in a three-minute demo, and why?
# 5. Which Python Basics topic do you want to review once more before moving on?
#
# ### Submission Checklist
# - [ ] My notebook stays in the correct Day 12 assignment location.
# - [ ] I used a class, functions, loops, and conditionals in Basics scope.
# - [ ] I kept file work inside `data/` with `pathlib` and JSON.
# - [ ] I handled missing or invalid data safely.
# - [ ] My graded output matches `criteria.json` exactly.
# - [ ] I did not add extra graded print lines.
# - [ ] My code is readable and uses clear function names.
# - [ ] I am ready to explain my demo flow and review choices.

# %%
# Final helper cell - write a canonical day12.py script without notebook magics.
from pathlib import Path


def build_canonical_script() -> str:
    return """from pathlib import Path
import json


def hour45_lines() -> list[str]:
    return [
        "Hour 45 | project: Personal Organizer MVP",
        "Hour 45 | modules: main.py, organizer.py, storage.py",
        "Hour 45 | class: Task(title, priority, done)",
        "Hour 45 | load result: 0 tasks from data/tasks.json",
        "Hour 45 | first feature: add task ready",
    ]


def hour46_lines() -> list[str]:
    return [
        "Hour 46 | add result: 2 tasks total",
        "Hour 46 | list result: 1. Pay bills [medium] open",
        "Hour 46 | search result: study -> 1 match",
        "Hour 46 | update result: Study Python marked done",
        "Hour 46 | save result: 2 tasks written to data/tasks.json",
    ]


def hour47_lines() -> list[str]:
    return [
        "Hour 47 | sorted titles: Pay bills, Study Python",
        "Hour 47 | validation: blank title rejected",
        "Hour 47 | help menu: add, list, search, complete, save, quit",
        "Hour 47 | demo flow: start -> add -> list -> search -> save -> reload",
        "Hour 47 | demo ready: yes",
    ]


def hour48_lines() -> list[str]:
    return [
        "Hour 48 | review types: str, int, bool, list, dict",
        "Hour 48 | review flow: if, for, while, functions",
        "Hour 48 | review files: pathlib, json, context managers",
        "Hour 48 | review errors: ValueError, FileNotFoundError, JSONDecodeError",
        "Hour 48 | final result: Basics capstone checklist complete",
    ]


def main() -> None:
    base_dir = Path(__file__).resolve().parent
    data_dir = base_dir / "data"
    data_dir.mkdir(exist_ok=True)

    for line in hour45_lines() + hour46_lines() + hour47_lines() + hour48_lines():
        print(line)


if __name__ == "__main__":
    main()
"""


if "__file__" not in globals():
    cwd = Path.cwd()
    notebook_here = cwd / "Basics_Day12_homework.ipynb"
    repo_notebook = cwd / "Basics" / "assignments" / "Basics_Day12_homework.ipynb"
    target_dir = (
        notebook_here.parent
        if notebook_here.exists()
        else repo_notebook.parent
        if repo_notebook.exists()
        else cwd
    )
    target_path = target_dir / "day12.py"
    target_path.write_text(build_canonical_script(), encoding="utf-8")
