# %% [markdown]
# # Python Basics - Day 9 Homework
#
# **Runbook alignment (Day 9, Hours 33-36):**
# - Hour 33: Functions (`def`, parameters, `return`)
# - Hour 34: Scope + common function mistakes
# - Hour 35: Functions with collections
# - Hour 36: Modules, imports, and creating `utils.py`
#
# This notebook is a **student template**. Complete each exercise using only Day 9 concepts.

# %% [markdown]
# ### Autograder Integration Requirements
#
# This assignment is graded automatically.
#
# - Keep your final solution deterministic.
# - Match required output labels exactly.
# - Avoid randomness unless seeded.
# - Do not rely on current date/time.
# - Keep your solution self-contained in Python 3.
# - CI converts submitted notebooks to `day9.py` and evaluates against `criteria.json`.

# %% [markdown]
# ---
# ## Part 1: Hour 33 - Functions (`def`, parameters, `return`)

# %% [markdown]
# ### Exercise 1.1: Function Refactor - Contact Helpers (graded)
#
# Create three functions:
# - `add_contact(contact_list, name)`
# - `list_contacts(contact_list)` (return a comma-separated string)
# - `search_contact(contact_list, query)` (return `True`/`False`)
#
# Then run deterministic checks so your solution can print these lines:
#
# - `Hour33 add_contact count: 3`
# - `Hour33 list_contacts: Ava, Ben, Cara`
# - `Hour33 search_contact('Ben'): True`
# - `Hour33 search_contact('Zoe'): False`
# - `Hour33 add(8, 5): 13`
# - `Hour33 subtract(10, 4): 6`

# %%
# Exercise 1.1 - Hour 33 graded outputs
contacts: list[str] = []


def add_contact(contact_list: list[str], name: str) -> None:
    # TODO: Append name to the contact list.
    pass


def list_contacts(contact_list: list[str]) -> str:
    # TODO: Return a comma-separated string in insertion order.
    return ""


def search_contact(contact_list: list[str], query: str) -> bool:
    # TODO: Return True if query exists, else False.
    return False


# TODO: Add Ava, Ben, Cara and print exact required lines.
# TODO: Also create add(a, b) and subtract(a, b) helper functions and print required lines.

# %% [markdown]
# ### Exercise 1.2: Return vs Print (practice)
#
# Write two short functions:
# - one that only prints a message
# - one that returns a value
#
# In comments, explain why `return` is required when the main program must reuse computed data.

# %%
# Exercise 1.2 - return vs print (practice)
# TODO: Implement one print-only function and one return-based function.
# TODO: Demonstrate the difference with a short example.

# %% [markdown]
# ---
# ## Part 2: Hour 34 - Scope + common function mistakes

# %% [markdown]
# ### Exercise 2.1: Scope-Safe Calculator Functions (graded)
#
# Implement:
# - `add(num1, num2)`
# - `subtract(num1, num2)`
# - `multiply(num1, num2=1)`
# - `divide(num1, num2)` with divide-by-zero guard
#
# Use parameters/returns only (no hidden global dependency), then print exactly:
#
# - `Hour34 add(9, 3): 12`
# - `Hour34 subtract(9, 3): 6`
# - `Hour34 multiply(9): 9`
# - `Hour34 divide(9, 3): 3.0`
# - `Hour34 divide(9, 0): Error: Cannot divide by zero!`
# - `Hour34 scope_policy: pass data via parameters`

# %%
# Exercise 2.1 - Hour 34 graded outputs


def add(num1: float, num2: float) -> float:
    # TODO
    return 0.0


def subtract(num1: float, num2: float) -> float:
    # TODO
    return 0.0


def multiply(num1: float, num2: float = 1) -> float:
    # TODO
    return 0.0


def divide(num1: float, num2: float):
    # TODO: Return error string on zero divisor.
    return ""


# TODO: Print exact required Hour 34 lines.

# %% [markdown]
# ### Exercise 2.2: Shadowing and Globals (practice)
#
# Create a tiny example showing variable shadowing, then refactor it by passing values in and returning values out.

# %%
# Exercise 2.2 - shadowing practice
score = 0

# TODO: Show a shadowing pitfall in comments.
# TODO: Refactor to a safe function like add_points(current_score, points).

# %% [markdown]
# ---
# ## Part 3: Hour 35 - Functions with collections

# %% [markdown]
# ### Exercise 3.1: Mutate vs Return New Collection (graded)
#
# Use raw contacts:
# `["  sarah jones ", "MARK smith", " tina turner  "]`
#
# Implement:
# - `normalize_contacts_new(contacts)` -> returns a new cleaned list
# - `normalize_contacts_inplace(contacts)` -> mutates in place
#
# Also implement a dictionary lookup helper for phone numbers.
# Print exactly:
#
# - `Hour35 normalized_new: ['Sarah Jones', 'Mark Smith', 'Tina Turner']`
# - `Hour35 original_after_new: ['  sarah jones ', 'MARK smith', ' tina turner  ']`
# - `Hour35 in_place: ['Sarah Jones', 'Mark Smith', 'Tina Turner']`
# - `Hour35 dict_lookup('ava'): 555-0101`
# - `Hour35 dict_lookup('zoe'): not found`
# - `Hour35 strategy_note: document mutation behavior in docstrings`

# %%
# Exercise 3.1 - Hour 35 graded outputs
raw_contacts = ["  sarah jones ", "MARK smith", " tina turner  "]


def normalize_contacts_new(contacts: list[str]) -> list[str]:
    """TODO: Return a cleaned list without changing input list."""
    return []


def normalize_contacts_inplace(contacts: list[str]) -> None:
    """TODO: Clean the provided list in place."""
    pass


def find_phone(phone_book: dict[str, str], name: str) -> str:
    # TODO: Return phone string or 'not found'.
    return ""


# TODO: Print exact required Hour 35 lines.

# %% [markdown]
# ### Exercise 3.2: Collection Function Contract (practice)
#
# Add short docstrings for both normalization functions that clearly state whether they mutate input or return a new list.

# %%
# Exercise 3.2 - docstring contract practice
# TODO: Add/adjust docstrings and write 2-3 comments explaining when each strategy is preferred.

# %% [markdown]
# ---
# ## Part 4: Hour 36 - Modules, imports, and `utils.py`

# %% [markdown]
# ### Exercise 4.1: Import Patterns + Custom Utility Functions (graded)
#
# Demonstrate:
# - `import math`
# - `from math import ceil`
# - helper-style functions similar to a `utils.py` module (`format_currency`, `make_header`, `safe_int`)
#
# Print exactly:
#
# - `Hour36 math.sqrt(81): 9.0`
# - `Hour36 ceil(3.14): 4`
# - `Hour36 format_currency(15.9): $15.90`
# - `Hour36 make_header('Age Checker'): --- AGE CHECKER ---`
# - `Hour36 safe_int('42'): 42`
# - `Hour36 import_warning: avoid filenames like random.py`

# %%
# Exercise 4.1 - Hour 36 graded outputs
import math
from math import ceil


# TODO: Implement helper functions equivalent to what you would place in utils.py.
def format_currency(amount: float) -> str:
    return ""


def make_header(text: str) -> str:
    return ""


def safe_int(raw: str) -> int:
    # Basics-safe conversion pattern for deterministic demo input.
    return 0


# TODO: Print exact required Hour 36 lines.

# %% [markdown]
# ### Exercise 4.2: Module Structure Plan (practice)
#
# Write a brief plan (comments or markdown) for splitting your code into:
# - `utils.py` (helpers)
# - `main.py` (program flow)
#
# Include one sentence on why running `main.py` from the correct folder matters.

# %%
# Exercise 4.2 - module split plan (practice)
# TODO: Add your short plan here.

# %% [markdown]
# ---
# ## Reflection Questions
#
# Answer briefly in the next markdown cell.
#
# 1. Why is `return` more reusable than `print()`?
# 2. What scope bug happens when you rely on globals inside functions?
# 3. When is mutating a list acceptable, and when is returning a new list safer?
# 4. What is one difference between `import module` and `from module import name`?
# 5. Why should you avoid naming files `random.py` or `math.py`?

# %% [markdown]
# ### Your Answers
#
# 1.
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# ---
# ## Submission Checklist
#
# Before submitting, verify:
#
# - [ ] All required code cells run without errors.
# - [ ] Hour 33 required lines print exactly.
# - [ ] Hour 34 required lines print exactly.
# - [ ] Hour 35 required lines print exactly.
# - [ ] Hour 36 required lines print exactly.
# - [ ] Output is deterministic and consistently ordered.
# - [ ] Function docstrings describe behavior clearly.

# %% [markdown]
# ---
# ## Autograder Helper - Canonical Output Contract (`day9.py`)
#
# Your final solution should be able to produce output lines that include:
#
# ```python
# Hour33 add_contact count: 3
# Hour33 list_contacts: Ava, Ben, Cara
# Hour33 search_contact('Ben'): True
# Hour33 search_contact('Zoe'): False
# Hour33 add(8, 5): 13
# Hour33 subtract(10, 4): 6
#
# Hour34 add(9, 3): 12
# Hour34 subtract(9, 3): 6
# Hour34 multiply(9): 9
# Hour34 divide(9, 3): 3.0
# Hour34 divide(9, 0): Error: Cannot divide by zero!
# Hour34 scope_policy: pass data via parameters
#
# Hour35 normalized_new: ['Sarah Jones', 'Mark Smith', 'Tina Turner']
# Hour35 original_after_new: ['  sarah jones ', 'MARK smith', ' tina turner  ']
# Hour35 in_place: ['Sarah Jones', 'Mark Smith', 'Tina Turner']
# Hour35 dict_lookup('ava'): 555-0101
# Hour35 dict_lookup('zoe'): not found
# Hour35 strategy_note: document mutation behavior in docstrings
#
# Hour36 math.sqrt(81): 9.0
# Hour36 ceil(3.14): 4
# Hour36 format_currency(15.9): $15.90
# Hour36 make_header('Age Checker'): --- AGE CHECKER ---
# Hour36 safe_int('42'): 42
# Hour36 import_warning: avoid filenames like random.py
# ```
