# %% [markdown]
# # Python Basics - Day 9 Homework
#
# **Runbook alignment (Day 9, Hours 33-36):**
#
# - **Hour 33:** Functions with `def`, parameters, and `return`
# - **Hour 34:** Scope, variable shadowing, common mistakes, and default parameters
# - **Hour 35:** Functions with collections, including mutate-vs-return decisions
# - **Hour 36:** Modules, imports, and planning a `utils.py` helper module
#
# Complete the graded exercises first, then use the practice prompts to strengthen the same ideas.

# %% [markdown]
# ### Autograder Integration Requirements
#
# This assignment is graded automatically.
#
# - Put all of your solution code directly in this notebook.
# - Your notebook may be converted to `day9.py` during grading.
# - Graded output must be deterministic and match `criteria.json` exactly.
# - Do not rely on live dates, randomness, hidden files, or outside state.
# - Avoid extra whitespace or extra print lines in graded output sections.
# - Keep the notebook name and directory unchanged.
# - Do not use notebook magics such as `%%writefile` in your final graded code.

# %% [markdown]
# ---
# ## Part 1: Hour 33 - Functions with `def`, parameters, and `return`
#
# ### Exercise 1.1: Reusable Shop Helpers (graded)
#
# Write functions that model the runbook goals for this hour:
#
# 1. Create `greet_user(name)` and **return** a greeting string.
# 2. Create `compute_order_total(unit_price, quantity)` and **return** the numeric total.
# 3. Create `format_receipt_line(item_name, total)` and **return** a formatted summary line.
# 4. In your final graded demo, show why returning values is more flexible than printing inside every helper.
#
# Use these deterministic starter values in your first pass:
#
# - `learner_name = "Ava"`
# - `item_name = "notebooks"`
# - `unit_price = 7`
# - `quantity = 3`

# %%
learner_name: str = "Ava"
item_name: str = "notebooks"
unit_price: int = 7
quantity: int = 3

def greet_user(name: str) -> str:
    """Return a greeting for one learner."""
    # TODO: Return a greeting string instead of printing inside the function.
    pass

def compute_order_total(unit_price: int, quantity: int) -> int:
    """Return the total cost for one line item."""
    # TODO: Multiply the two parameters and return the result.
    pass

def format_receipt_line(item_name: str, total: int) -> str:
    """Return a short receipt summary for display."""
    # TODO: Return a string such as "notebooks -> 21".
    pass

# %% [markdown]
# ### Exercise 1.2: Calculator Refactor (practice)
#
# Refactor a tiny calculator into reusable helpers:
#
# - `add(a, b)`
# - `subtract(a, b)`
# - `multiply(a, b)`
# - `describe_result(operation_name, answer)`
#
# Focus on readable names and returning values first, then printing only in the final demo block.

# %%
first_number: int = 10
second_number: int = 4

def add(a: int, b: int) -> int:
    # TODO: Return the sum.
    pass

def subtract(a: int, b: int) -> int:
    # TODO: Return the difference.
    pass

def multiply(a: int, b: int) -> int:
    # TODO: Return the product.
    pass

def describe_result(operation_name: str, answer: int) -> str:
    # TODO: Return a sentence that uses both parameters.
    pass

# %% [markdown]
# ---
# ## Part 2: Hour 34 - Scope, shadowing, and default parameters
#
# ### Exercise 2.1: Price Helpers Without Global Bugs (graded)
#
# Use functions to avoid common scope mistakes:
#
# 1. Keep `global_discount_rate` unchanged outside your helper functions.
# 2. Write `apply_discount(price, discount_rate=0.10)` using a default parameter.
# 3. Write `build_greeting(name, greeting="Hello")` and allow a custom greeting override.
# 4. Write one short example that demonstrates local shadowing without changing the global `score`.
#
# Starter values for deterministic testing:
#
# - `global_discount_rate = 0.10`
# - `sample_price = 50.0`
# - `score = 0`
# - `name = "Mia"`

# %%
global_discount_rate: float = 0.10
sample_price: float = 50.0
score: int = 0
learner_name_scope: str = "Mia"

def apply_discount(price: float, discount_rate: float = 0.10) -> float:
    """Return a discounted price instead of mutating global state."""
    # TODO: Return the discounted price rounded only if you decide it is needed.
    pass

def build_greeting(name: str, greeting: str = "Hello") -> str:
    """Return a greeting using a default parameter."""
    # TODO: Return a greeting string.
    pass

def explain_shadowing(local_score: int) -> str:
    """Show the difference between a local variable and the global score."""
    # TODO: Return a sentence that mentions both the local and global score values.
    pass

# %% [markdown]
# ### Exercise 2.2: Common Function Mistakes Checklist (practice)
#
# Use comments or short strings to record at least three mistakes beginners make with functions. Examples:
#
# - Forgetting to call the function after defining it
# - Printing a value when later code actually needs `return`
# - Depending on global variables instead of passing parameters
# - Reusing the same variable name and causing confusion

# %%
common_function_mistakes: list[str] = [
    "Forgetting parentheses when calling a function",
    "Printing when the program needs a returned value",
    "Using globals when parameters would be clearer"
]

def summarize_mistakes(mistakes: list[str]) -> str:
    """Return one short summary sentence about common mistakes."""
    # TODO: Join or summarize the list into one readable sentence.
    pass

# %% [markdown]
# ---
# ## Part 3: Hour 35 - Functions with collections
#
# ### Exercise 3.1: Mutate or Return New Data? (graded)
#
# Build helpers for lists and dictionaries.
#
# 1. Write `add_name_in_place(names, new_name)` that **mutates** the original list.
# 2. Write `uppercase_copy(names)` that returns a **new** list and keeps the original safe.
# 3. Write `add_contact(contacts, name, phone)` and clearly document whether your function mutates or returns a new dictionary.
# 4. Add a short docstring note whenever a function changes a collection in place.
#
# Starter collections:
#
# - `roster = ["ava", "ben"]`
# - `contact_book = {"Ava": "555-0101", "Ben": "555-0102"}`

# %%
roster: list[str] = ["ava", "ben"]
contact_book: dict[str, str] = {
    "Ava": "555-0101",
    "Ben": "555-0102"
}

def add_name_in_place(names: list[str], new_name: str) -> None:
    """Mutate the provided list by appending one name."""
    # TODO: Append the new name to the original list.
    pass

def uppercase_copy(names: list[str]) -> list[str]:
    """Return a new uppercase list without mutating the original."""
    # TODO: Build and return a fresh list.
    pass

def add_contact(contacts: dict[str, str], name: str, phone: str):
    """Add one contact and make your mutate-vs-return choice explicit."""
    # TODO: Update the contact structure and document your choice in the docstring or comments.
    pass

# %% [markdown]
# ### Exercise 3.2: Collection Design Notes (practice)
#
# Answer these design questions in comments or short strings:
#
# 1. When is mutation useful?
# 2. When is returning a new collection safer?
# 3. How can a docstring warn another developer about side effects?

# %%
design_notes: dict[str, str] = {
    "mutation": "",
    "return_new": "",
    "docstrings": ""
}

def format_design_notes(notes: dict[str, str]) -> list[str]:
    """Return a readable list of study notes about collection decisions."""
    # TODO: Turn the notes dictionary into a list of readable summary strings.
    return []

# %% [markdown]
# ---
# ## Part 4: Hour 36 - Modules, imports, and `utils.py`
#
# ### Exercise 4.1: Import Style and Helper Planning (graded)
#
# This hour is about understanding how files connect.
#
# 1. Use `import math` and show a deterministic example such as `math.sqrt(81)`.
# 2. Explain the difference between `import module` and `from module import name`.
# 3. Create a helper such as `format_username(name)` and label it as something you would normally place in `utils.py`.
# 4. Include one warning about bad file names like `random.py` or `math.py`.
#
# For this notebook, keep everything self-contained even if you describe how the same helper would move into a separate module in a normal `.py` project.

# %%
import math

sample_module_name: str = "student_utils.py"

def describe_import_styles() -> list[str]:
    """Return short notes about the two import styles from class."""
    # TODO: Include one note for import-module style and one note for from-module-import style.
    return []

def format_username(name: str) -> str:
    """Pretend this helper lives in utils.py in a regular Python project."""
    # TODO: Return a lowercase username with extra spaces removed.
    pass

def module_naming_warning(filename: str) -> str:
    """Return a warning message if a filename shadows a standard-library module."""
    # TODO: Warn about names like random.py or math.py.
    pass

# %% [markdown]
# ### Exercise 4.2: `utils.py` Planning Notes (practice)
#
# Write a short plan for how you would split a larger program into `main.py` and `utils.py`.
#
# Suggested headings:
#
# - Functions that belong in `utils.py`
# - Code that should stay in `main.py`
# - One import statement you would use
# - One working-directory or naming mistake to avoid

# %%
module_plan: dict[str, str] = {
    "utils_functions": "",
    "main_file": "",
    "import_statement": "",
    "warning": ""
}

def module_plan_summary(plan: dict[str, str]) -> str:
    """Return a one-paragraph summary of the planned file split."""
    # TODO: Build and return one concise summary string.
    pass

# %% [markdown]
# ---
# ## Reflection Questions
#
# Answer briefly in the next markdown cell.
#
# 1. When should you use `return` instead of `print`?
# 2. Why is passing a parameter safer than depending on a global variable?
# 3. What clues help you decide whether a collection function should mutate data?
# 4. Why is `math.sqrt(...)` sometimes clearer than importing `sqrt` directly?
# 5. What is one file-naming mistake you will avoid after Day 9?

# %% [markdown]
# ### Your Answers
#
# 1.
#
# 2.
#
# 3.
#
# 4.
#
# 5.

# %% [markdown]
# ---
# ## Submission Checklist
#
# Before submitting, verify:
#
# - [ ] All required code cells run without errors
# - [ ] Hour 33 helpers use parameters and `return`
# - [ ] Hour 34 work shows local scope and default parameters clearly
# - [ ] Hour 35 work explains mutate-vs-return decisions
# - [ ] Hour 36 work explains import styles and naming safety
# - [ ] Outputs are deterministic and exactly formatted for graded lines
# - [ ] Reflection questions are answered
#
# ### Autograder Checklist
#
# - [ ] Output lines match `criteria.json` exactly
# - [ ] No extra punctuation or whitespace appears in graded output
# - [ ] Notebook filename/location remain unchanged
# - [ ] Conversion target remains `day9.py`

# %% [markdown]
# ---
# ## Autograder Helper - Canonical Output Contract (`day9.py`)
#
# Your notebook solution should be able to produce output consistent with this contract:
#
# ```python
# # Canonical script for Day 9 grading by autograder (day9.py)
# def main():
#     # Hour 33
#     print("Function defined: greet_user(name)")
#     print("Greeting return: Hello, Ava!")
#     print("Order total return: 21")
#     print("Receipt line: notebooks -> 21")
#     print("Return beats print: saved result for later use")
#
#     # Hour 34
#     print("Global rate stays: 0.1")
#     print("Scoped discount on 50.0 -> 45.0")
#     print("Shadowing demo: local score = 5, global score = 0")
#     print("Default greeting: Hello, Mia!")
#     print("Custom greeting: Welcome back, Mia!")
#
#     # Hour 35
#     print("Mutated roster: ['ava', 'ben', 'cora']")
#     print("Returned uppercase copy: ['AVA', 'BEN', 'CORA']")
#     print("Original roster preserved after copy: ['ava', 'ben', 'cora']")
#     print("Updated contacts: Ava=555-0101, Ben=555-0102, Cora=555-0103")
#     print("Docstring note: say whether your function mutates or returns new data")
#
#     # Hour 36
#     print("math.sqrt(81) -> 9.0")
#     print("Module import style: math.sqrt keeps the module namespace clear")
#     print("Specific import style: sqrt(49) -> 7.0")
#     print("Custom helper preview: format_username('Charles') -> charles")
#     print("Naming warning: do not name your file random.py")
#
# if __name__ == "__main__":
#     main()
# ```
