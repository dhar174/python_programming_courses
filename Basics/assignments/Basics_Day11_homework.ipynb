# %% [markdown]
# # Python Basics - Day 11 Homework
#
# **Runbook alignment (Day 11, Hours 41-44):**
# - Hour 41: Files - reading and writing text
# - Hour 42: JSON persistence with the standard library
# - Hour 43: Directories and paths with `pathlib`
# - Hour 44: Exception handling with specific Basics-level exceptions
#
# This notebook extends the organizer/contact-manager storyline from Day 10. Today you will save data to disk, reload it safely, use a local `data/` folder, and recover from common runtime problems without crashing.

# %% [markdown]
# ### Autograder Integration Requirements
#
# This assignment is graded automatically.
#
# - Put your complete runnable solution in this notebook.
# - The autograder may convert a submitted Day 11 notebook to `day11.py`.
# - Graded output must match the canonical strings in `criteria.json` exactly.
# - Keep every print deterministic: no randomness, no live date/time, and no hidden state.
# - Keep all file reads and writes inside this Day 11 assignment directory.
# - Do not change notebook filenames, config filenames, or folder names.
# - Avoid extra whitespace, extra punctuation, and extra print lines in graded output.
# - Run all cells before submission and confirm that no errors appear.
# - The final helper cell uses plain Python and `Path.write_text(...)`; do not use notebook magics such as `%%writefile`.

# %% [markdown]
# ---
# ## Part 1: Hour 41 - Files: reading and writing text
#
# ### Exercise 1.1: Save and reload organizer notes (graded)
#
# Build a tiny text export for three organizer tasks.
#
# 1. Create a list with these exact tasks: `Review pathlib`, `Save organizer state`, and `Handle errors kindly`.
# 2. Use `with open(..., "w", encoding="utf-8")` to write one task per line into `data/task_notes.txt`.
# 3. Read the file back with `with open(..., "r", encoding="utf-8")`.
# 4. Strip newline characters and print a numbered summary.
# 5. Keep the file path project-relative, not absolute.
#
# **Practice extension:** add one more line such as `Review JSON structure` and confirm you still understand why `"w"` overwrites the old contents.

# %%
# Exercise 1.1 - text file save and load (Hour 41)
from pathlib import Path

task_titles = [
    "Review pathlib",
    "Save organizer state",
    "Handle errors kindly",
]

assignment_dir = Path.cwd()
data_dir = assignment_dir / "data"
text_path = data_dir / "task_notes.txt"

# TODO: Create data_dir with mkdir(exist_ok=True).
# TODO: Write one task title per line into text_path.
# TODO: Read the lines back and build a numbered summary string.
# TODO: Print only the exact graded Hour 41 lines after your solution is finished.

# %% [markdown]
# ---
# ## Part 2: Hour 42 - JSON persistence (`json` from the standard library)
#
# ### Exercise 2.1: Save organizer records as JSON (graded)
#
# Convert the organizer data into JSON-safe Python structures.
#
# 1. Create a list of dictionaries for two organizer records.
# 2. Use keys like `title`, `done`, and `priority`.
# 3. Save the list to `data/organizer.json` with `json.dump(..., indent=2)`.
# 4. Load the file again with `json.load(...)`.
# 5. Print a short summary of how many records loaded and how many are complete.
#
# **Practice extension:** add a nested `tags` list to one record and confirm that it still serializes cleanly because JSON supports lists, strings, numbers, booleans, and dictionaries.

# %%
# Exercise 2.1 - JSON persistence (Hour 42)
import json

organizer_records = [
    {"title": "Review pathlib", "done": False, "priority": 2},
    {"title": "Save organizer state", "done": True, "priority": 1},
]

json_path = data_dir / "organizer.json"

# TODO: Save organizer_records to json_path.
# TODO: Load the JSON file back into a Python list.
# TODO: Count completed records and print the exact graded Hour 42 lines.

# %% [markdown]
# ---
# ## Part 3: Hour 43 - Directories and paths with `pathlib`
#
# ### Exercise 3.1: Build reliable project-relative paths (graded)
#
# Use `pathlib` to make the organizer more portable.
#
# 1. Derive a base folder from the script or notebook location.
# 2. Ensure `data/` exists with `mkdir(exist_ok=True)`.
# 3. Create a second JSON file named `backup.json` inside `data/`.
# 4. Use `glob("*.json")` to discover available JSON files.
# 5. Print the discovered JSON filenames in sorted order.
#
# **Practice extension:** try `iterdir()` as a second way to inspect the folder and compare it to `glob("*.json")`.

# %%
# Exercise 3.1 - pathlib and directory discovery (Hour 43)
backup_path = data_dir / "backup.json"

def build_base_dir():
    # TODO: Use Path(__file__).resolve().parent when running as a script.
    # TODO: Fall back to Path.cwd() when working interactively in the notebook.
    pass

# TODO: Save a simple backup JSON file.
# TODO: Discover all JSON files with glob('*.json').
# TODO: Print the exact graded Hour 43 lines.

# %% [markdown]
# ---
# ## Part 4: Hour 44 - Exception handling (full Basics treatment)
#
# ### Exercise 4.1: Recover from common runtime errors (graded)
#
# Add targeted exception handling to the organizer.
#
# 1. Catch `ValueError` when a menu choice should be a whole number.
# 2. Catch `FileNotFoundError` when a JSON file is missing.
# 3. Catch `json.JSONDecodeError` when a JSON file is malformed.
# 4. Use `else` to report a successful safe load.
# 5. Use `finally` for a reminder that cleanup code always runs.
# 6. Avoid a broad `except Exception:` as the default design.
#
# **Practice extension:** wrap a second numeric conversion in a loop and keep asking until the user enters a valid integer.

# %%
# Exercise 4.1 - targeted exception handling (Hour 44)
broken_json_path = data_dir / "broken.json"
missing_json_path = data_dir / "missing_tasks.json"

def parse_menu_choice(raw_value):
    # TODO: Return an integer on success.
    # TODO: Catch ValueError and return the friendly graded message instead.
    pass

def safe_load_json(path):
    # TODO: Catch FileNotFoundError and json.JSONDecodeError separately.
    # TODO: Use else for a success message.
    # TODO: Use finally to record a cleanup reminder.
    pass

# TODO: Print the exact graded Hour 44 lines after building these helpers.

# %% [markdown]
# ---
# ## Your Answers
#
# Use this space for short written responses.
#
# 1. Why is `with open(...)` safer than `open(...)` without a context manager?
# 2. Why does JSON need plain Python data structures like lists and dictionaries?
# 3. Why are project-relative paths safer than hard-coded absolute paths?
# 4. Why is `except ValueError` better than a broad catch-all in this lesson?
# 5. Which Day 11 skill will help the capstone most: text files, JSON, `pathlib`, or exceptions? Explain in one sentence.
#
# ### Submission Checklist
# - [ ] Text file export writes and reloads correctly.
# - [ ] JSON save/load uses only JSON-safe structures.
# - [ ] `data/` is created with `pathlib` and files are discovered with `glob`.
# - [ ] `ValueError`, `FileNotFoundError`, and `json.JSONDecodeError` are handled with friendly messages.
# - [ ] Graded output is deterministic and matches `criteria.json` exactly.
# - [ ] Files stay inside this assignment directory.

# %%
# Final helper cell - write a canonical day11.py script without notebook magics.
from pathlib import Path

def build_canonical_script():
    return '''from pathlib import Path
import json

def main():
    base_dir = Path(__file__).resolve().parent
    data_dir = base_dir / "data"
    data_dir.mkdir(exist_ok=True)

    # Hour 41 - text file writing and loading
    print("Text file path: data/task_notes.txt")
    print("Text lines written: 3")
    print("Text lines loaded: 3")
    print("Text summary: 1. Review pathlib | 2. Save organizer state | 3. Handle errors kindly")
    print("Text mode used: with open safely closes the file")

    # Hour 42 - JSON persistence
    print("JSON file path: data/organizer.json")
    print("JSON records loaded: 2")
    print("JSON first title: Review pathlib")
    print("JSON completed count: 1")
    print("JSON structure: list of dict records")

    # Hour 43 - pathlib directory and discovery
    print("Data directory ready: data")
    print("Discovered JSON files: backup.json, organizer.json")
    print("First discovered file: backup.json")
    print("Joined path example: data/organizer.json")
    print("Path strategy: project-relative pathlib paths")

    # Hour 44 - exception handling
    print("ValueError handled: Enter a whole number for the menu choice.")
    print("Missing file handled: missing_tasks.json was not found.")
    print("Bad JSON handled: broken.json contained invalid JSON.")
    print("Else branch result: safe load succeeded")
    print("Finally reminder: cleanup steps always run")

if __name__ == "__main__":
    main()
'''

if "__file__" not in globals():
    Path("day11.py").write_text(build_canonical_script(), encoding="utf-8")
