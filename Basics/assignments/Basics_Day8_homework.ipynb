# %% [markdown]
# # Python Basics - Day 8 Homework
#
# **Runbook alignment (Day 8, Hours 29-32):**
# - Hour 29: Menu loops (CLI pattern)
# - Hour 30: Input validation (Basics approach)
# - Hour 31: Mini-project - CLI Contact Manager (in-memory)
# - Hour 32: Checkpoint 4 - Control flow assessment
#
# This assignment follows the Session 8 outcomes in the instructor runbook and keeps scope strictly in Python Basics.

# %% [markdown]
# ### Autograder Integration Requirements
#
# This assignment is graded automatically.
#
# - Put your complete runnable solution in this notebook.
# - CI converts a submitted Day 8 notebook to `day8.py`.
# - Graded output must match canonical strings in `criteria.json` exactly.
# - Keep output deterministic: no randomness, no live date/time, no external files.
# - Numeric formatting must match exactly where specified.
# - Do not rename files or move directories.

# %% [markdown]
# ---
# ## Part 1: Hour 29 - Menu loops (CLI pattern)

# %% [markdown]
# ### Exercise 1.1: Menu Loop Routing (graded)
#
# Create a loop-driven CLI simulation for options `1-4` with this deterministic input sequence:
# `["1", "2", "3", "4"]`
#
# Print these exact lines (in order):
# - `Menu display: [1] Add [2] List [3] Search [4] Quit`
# - `Menu option selected: 1 -> add`
# - `Menu option selected: 2 -> list`
# - `Menu option selected: 3 -> search`
# - `Menu option selected: 4 -> quit`
# - `Menu loop ended: user requested quit`

# %%
# Exercise 1.1 - menu loop routing (Hour 29)
menu_inputs: list[str] = ["1", "2", "3", "4"]

# TODO: Build a while loop that processes menu_inputs one value at a time.
# TODO: Route actions with if/elif and print the exact graded lines.
# TODO: End the loop when quit is selected.

# %% [markdown]
# ### Exercise 1.2: Invalid Choice Guard (practice)
#
# Extend your menu loop so invalid choices (for example `"9"`) print a helpful message and continue prompting.
# Use deterministic pseudo-input data in code (no real-time interactive input required).

# %%
# Exercise 1.2 - invalid menu choice handling (practice)
menu_inputs_with_invalid: list[str] = ["9", "2", "4"]

# TODO: Print a clear invalid-choice message for unsupported options.
# TODO: Continue loop safely after invalid input.

# %% [markdown]
# ---
# ## Part 2: Hour 30 - Input validation (Basics approach)

# %% [markdown]
# ### Exercise 2.1: Safe Integer Entry (graded)
#
# Use this deterministic sequence to simulate user input:
# `["abc", "-5", "12"]`
#
# Apply a basic `.isdigit()` guard and print these exact lines:
# - `Input 'abc' -> invalid integer`
# - `Input '-5' -> invalid for isdigit guard`
# - `Input '12' -> accepted integer 12`
# - `Validated number doubled: 24`
# - `Validation note: isdigit() does not accept negatives or decimals`

# %%
# Exercise 2.1 - safe integer validation (Hour 30)
raw_inputs: list[str] = ["abc", "-5", "12"]

# TODO: Re-prompt until valid according to a basic isdigit() guard.
# TODO: Convert only after validation.
# TODO: Print exact graded lines for invalid and valid cases.

# %% [markdown]
# ### Exercise 2.2: Optional Extension - Negative Integers (practice)
#
# Optional: support negatives by checking `raw.lstrip('-').isdigit()` after confirming `raw` is not just `"-"`.
# Document one limitation that still remains for decimal values.

# %%
# Exercise 2.2 - optional negative support (practice)
optional_inputs: list[str] = ["-12", "3.5", "7"]

# TODO: Implement optional negative integer handling.
# TODO: Keep messaging clear when decimal input is rejected.

# %% [markdown]
# ---
# ## Part 3: Hour 31 - Mini-project: CLI Contact Manager (in-memory)

# %% [markdown]
# ### Exercise 3.1: Contact Manager Core Features (graded)
#
# Build a menu-style in-memory Contact Manager with required actions:
# - Add contact (name, phone)
# - List contacts
# - Search by name
# - Delete by name
#
# For deterministic grading, print these exact lines:
# - `Added contact: Ava -> 555-0101`
# - `Added contact: Ben -> 555-0102`
# - `List contacts: Ava (555-0101), Ben (555-0102)`
# - `Search 'Ava': 555-0101`
# - `Delete 'Ben': removed`
# - `Delete 'Zoe': not found`

# %%
# Exercise 3.1 - contact manager core (Hour 31)
contacts: dict[str, str] = {}

# TODO: Add two contacts deterministically (Ava, Ben).
# TODO: Implement list, search, and delete operations.
# TODO: Avoid KeyError by checking existence before delete.
# TODO: Print exact graded lines.

# %% [markdown]
# ### Exercise 3.2: UX and Data Quality (practice)
#
# Practice clean UX messaging for duplicate names and case sensitivity.
# Decide and document one policy for handling `"ava"` vs `"Ava"`.

# %%
# Exercise 3.2 - contact manager UX refinements (practice)
sample_names: list[str] = ["Ava", "ava", "AVA"]

# TODO: Choose a normalization strategy or explicit case-sensitive policy.
# TODO: Print confirmations so users always know what happened.

# %% [markdown]
# ---
# ## Part 4: Hour 32 - Checkpoint 4: Control flow assessment

# %% [markdown]
# ### Exercise 4.1: CLI To-Do Manager Checkpoint (graded)
#
# Build an in-memory To-Do Manager with:
# - Menu loop until quit
# - Add task
# - List tasks
# - Mark complete
# - Delete task
# - Basic input validation (non-empty task)
#
# For deterministic grading, print these exact lines:
# - `Task added: Finish checkpoint`
# - `Task added: Review loops`
# - `Task completed: Finish checkpoint`
# - `Task deleted: Review loops`
# - `Remaining tasks: Finish checkpoint [done]`
# - `Checkpoint 4 status: pass`

# %%
# Exercise 4.1 - checkpoint to-do manager (Hour 32)
tasks: list[dict[str, object]] = []

# TODO: Add, complete, delete, and list tasks.
# TODO: Keep tasks in memory for the full run.
# TODO: Include non-empty task-name validation.
# TODO: Print exact graded lines.

# %% [markdown]
# ### Exercise 4.2: Boundary Testing Notes (practice)
#
# Write short notes describing how you tested:
# - invalid menu choice
# - missing contact/task delete path
# - empty task name
# - repeated loop interactions

# %%
# Exercise 4.2 - boundary test notes (practice)
# TODO: Add comments describing your boundary-case tests.

# %% [markdown]
# ---
# ## Reflection Questions
#
# Answer briefly in the next markdown cell.
#
# 1. Why is a menu loop useful for CLI programs?
# 2. What is one limitation of `.isdigit()`?
# 3. How did you avoid `KeyError` in Contact Manager?
# 4. Which checkpoint boundary case was hardest to test?
# 5. What would you refactor first if this app grew larger?

# %% [markdown]
# ### Your Answers
#
# 1.
#
# 2.
#
# 3.
#
# 4.
#
# 5.

# %% [markdown]
# ---
# ## Submission Checklist
#
# Before submitting, verify:
#
# - [ ] All required code cells run without errors
# - [ ] Hour 29 menu loop routing is complete
# - [ ] Hour 30 input validation includes clear re-prompts
# - [ ] Hour 31 Contact Manager required actions work
# - [ ] Hour 32 To-Do Manager checkpoint requirements work
# - [ ] Outputs are deterministic and exactly formatted
# - [ ] Reflection questions are answered
#
# ### Autograder Checklist
#
# - [ ] Output lines match `criteria.json` exactly
# - [ ] No extra punctuation/whitespace in graded lines
# - [ ] Notebook filename/location unchanged
# - [ ] Conversion target remains `day8.py`

# %% [markdown]
# ---
# ## Autograder Helper - Canonical Output Contract (`day8.py`)
#
# Your notebook solution should be able to produce output consistent with this contract:
#
# ```python
# # Canonical script for Day 8 grading by autograder (day8.py)
# def main():
#     # Hour 29
#     print("Menu display: [1] Add [2] List [3] Search [4] Quit")
#     print("Menu option selected: 1 -> add")
#     print("Menu option selected: 2 -> list")
#     print("Menu option selected: 3 -> search")
#     print("Menu option selected: 4 -> quit")
#     print("Menu loop ended: user requested quit")
#
#     # Hour 30
#     print("Input 'abc' -> invalid integer")
#     print("Input '-5' -> invalid for isdigit guard")
#     print("Input '12' -> accepted integer 12")
#     print("Validated number doubled: 24")
#     print("Validation note: isdigit() does not accept negatives or decimals")
#
#     # Hour 31
#     print("Added contact: Ava -> 555-0101")
#     print("Added contact: Ben -> 555-0102")
#     print("List contacts: Ava (555-0101), Ben (555-0102)")
#     print("Search 'Ava': 555-0101")
#     print("Delete 'Ben': removed")
#     print("Delete 'Zoe': not found")
#
#     # Hour 32
#     print("Task added: Finish checkpoint")
#     print("Task added: Review loops")
#     print("Task completed: Finish checkpoint")
#     print("Task deleted: Review loops")
#     print("Remaining tasks: Finish checkpoint [done]")
#     print("Checkpoint 4 status: pass")
#
# if __name__ == "__main__":
#     main()
# ```
