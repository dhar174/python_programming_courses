# %% [markdown]
# # Python Basics - Day 10 Homework
#
# **Runbook alignment (Day 10, Hours 37-40):**
# - Hour 37: Intro classes - objects, attributes, and methods
# - Hour 38: Collections of objects and searching
# - Hour 39: Basic encapsulation and data validation
# - Hour 40: Checkpoint 5 - functions, modules, and intro OOP
#
# This notebook follows the Session 10 runbook outcomes and stays inside Python Basics scope.

# %% [markdown]
# ### Autograder Integration Requirements
#
# This assignment is graded automatically.
#
# - Put your complete runnable solution in this notebook.
# - CI may convert a submitted Day 10 notebook to `day10.py`.
# - Graded output must match canonical strings in `criteria.json` exactly.
# - Keep output deterministic: no randomness, no live date/time, and no hidden state.
# - Do not read or write files outside this assignment directory.
# - Avoid extra whitespace, extra print lines, or changed punctuation in graded output.
# - Keep the notebook name and directory unchanged.
# - Do not use notebook magics such as `%%writefile` in your final graded code.

# %% [markdown]
# ---
# ## Part 1: Hour 37 - Intro classes, objects, attributes, methods

# %% [markdown]
# ### Exercise 1.1: Build a `Contact` class (graded)
#
# Create a Basics-friendly class that matches the runbook lab:
#
# 1. Define `Contact` with `__init__(name, phone)`.
# 2. Store `name` and `phone` as instance attributes.
# 3. Add `display()` that returns `"Name -> phone"`.
# 4. Add `announce_ready()` that returns `"Name is ready to contact."`.
# 5. Instantiate `Ada` with phone `5551234` and use method calls in your graded demo.

# %%
# Exercise 1.1 - class basics (Hour 37)
starter_name: str = "Ada"
starter_phone: str = "5551234"

class Contact:
    """Store one contact with a name and phone number."""

    def __init__(self, name: str, phone: str) -> None:
        # TODO: Save two instance attributes on self.
        pass

    def display(self) -> str:
        # TODO: Return a string like "Ada -> 5551234".
        pass

    def announce_ready(self) -> str:
        # TODO: Return a sentence that uses the contact name.
        pass

# %% [markdown]
# ### Exercise 1.2: Create more than one object (practice)
#
# Create at least one more `Contact` object and compare the outputs of `display()`.
# Notice that each object stores its own attribute values.

# %%
# Exercise 1.2 - more objects (practice)
second_name: str = "Grace"
second_phone: str = "5552222"

# TODO: Create another Contact object.
# TODO: Print or inspect both display() results.

# %% [markdown]
# ---
# ## Part 2: Hour 38 - Collections of objects and searching

# %% [markdown]
# ### Exercise 2.1: Search a list of contacts (graded)
#
# Refactor the contact manager idea from dictionary records to objects:
#
# 1. Build a list containing `Ada`, `Grace`, and `Linus` `Contact` objects.
# 2. Write `normalize_name(name)` so searching ignores case and outer spaces.
# 3. Write `find_contact_by_name(contacts, target_name)` that returns the matching object or `None`.
# 4. Search for `"grace"` and prove it matches `Grace`.
# 5. Update the found contact's phone to `5553333`.
# 6. Print the object count to show the collection still contains three records.

# %%
# Exercise 2.1 - collections of objects (Hour 38)
target_lookup: str = "grace"
missing_lookup: str = "Maya"

def normalize_name(name: str) -> str:
    # TODO: Return a lowercase, trimmed version of the name.
    pass

def find_contact_by_name(contacts: list[Contact], target_name: str):
    # TODO: Loop through contacts and return the first matching object.
    # TODO: Return None if no match is found.
    pass

# %% [markdown]
# ### Exercise 2.2: Show contact cards with a loop (practice)
#
# Write a helper that loops through a list of `Contact` objects and returns a list of display strings.
# This is good practice for menu-driven programs that need readable list output.

# %%
# Exercise 2.2 - listing objects (practice)
def list_contact_cards(contacts: list[Contact]) -> list[str]:
    # TODO: Return one display string per contact object.
    pass

# %% [markdown]
# ---
# ## Part 3: Hour 39 - Basic encapsulation and data validation

# %% [markdown]
# ### Exercise 3.1: Keep validation inside the class (graded)
#
# Extend your `Contact` class so business rules stay in one place:
#
# 1. Add `update_phone(new_phone)` to `Contact`.
# 2. Accept a new phone only if it contains digits only and has length 7.
# 3. Return `True` when the update succeeds.
# 4. Return `False` when the update is invalid and keep the previous phone unchanged.
# 5. Test with `"5554444"` and then with `"55-abc"`.
# 6. Write one short explanation for why validation belongs in the class instead of only in UI code.

# %%
# Exercise 3.1 - validation (Hour 39)
valid_phone: str = "5554444"
invalid_phone: str = "55-abc"

# TODO: Update the Contact class above so update_phone(...) enforces simple rules.

def validation_explanation() -> str:
    # TODO: Return one sentence explaining why class methods are a good place for validation.
    pass

# %% [markdown]
# ### Exercise 3.2: Optional extension - normalize digits for storage (practice)
#
# Optional: strip spaces before validation so input like `" 5554444 "` can still become a clean stored phone number.
# Keep the rule simple and stay inside Basics scope.

# %%
# Exercise 3.2 - optional normalization (practice)
raw_phone_inputs: list[str] = [" 5554444 ", "555-4444", "abc"]

# TODO: Try optional whitespace stripping before your digit-only check.
# TODO: Record which inputs should still be rejected.

# %% [markdown]
# ---
# ## Part 4: Hour 40 - Checkpoint 5 planning (functions, modules, intro OOP)

# %% [markdown]
# ### Exercise 4.1: Plan a small CLI Organizer (graded)
#
# Use the runbook checkpoint requirements to sketch a small in-memory organizer:
#
# - Menu loop until quit
# - At least three functions
# - At least one custom module
# - At least one class used to store a record
# - Features: add, list, search
#
# For the graded contract, include these exact ideas in your plan:
#
# - Functions: `add_contact`, `list_contacts`, `find_contact`
# - Module split: `main.py` handles the menu and `utils.py` normalizes search
# - Class name: `Contact`
# - Readiness note: modular, readable, in-memory organizer

# %%
# Exercise 4.1 - checkpoint planning (Hour 40)
checkpoint_functions: list[str] = ["add_contact", "list_contacts", "find_contact"]
checkpoint_plan: dict[str, str] = {
    "main": "",
    "utils": "",
    "class_name": "Contact",
    "features": "add, list, search",
    "readiness": ""
}

def checkpoint_summary(plan: dict[str, str], functions: list[str]) -> str:
    # TODO: Return one sentence summarizing module split and readiness.
    pass

# %% [markdown]
# ---
# ## Reflection Questions
#
# Answer briefly in the next markdown cell.
#
# 1. What does `self` represent inside a method?
# 2. Why is name normalization useful when searching objects?
# 3. Why is validation stronger when it lives in the class?
# 4. What should move to `utils.py` in your checkpoint organizer?
# 5. Which duplicated step would you reduce with functions?

# %% [markdown]
# ### Your Answers
#
# 1.
#
# 2.
#
# 3.
#
# 4.
#
# 5.

# %% [markdown]
# ---
# ## Submission Checklist
#
# Before submitting, verify:
#
# - [ ] `Contact` uses `__init__`, attributes, and methods clearly
# - [ ] Searching works on a list of objects and handles a missing name safely
# - [ ] Validation rejects invalid phone updates without crashing
# - [ ] The checkpoint plan shows functions, a module split, and one class
# - [ ] Output lines are deterministic and formatted exactly for graded sections
# - [ ] Reflection questions are answered
#
# Checkpoint rubric reminders:
#
# - Correctness: requirements work for typical test cases
# - Required concepts: classes, methods, object search, validation, modular planning
# - Readability: clear names, 4-space indentation, f-strings where useful
# - Robustness: invalid inputs are handled without obvious crashes
#
# Autograder checklist:
#
# - [ ] Output matches `criteria.json` exactly
# - [ ] No extra punctuation or whitespace appears in graded lines
# - [ ] Notebook filename and directory remain unchanged
# - [ ] Conversion target remains `day10.py`

# %% [markdown]
# ---
# ## Autograder Helper - Canonical Output Contract (`day10.py`)
#
# Your notebook solution should be able to produce output consistent with this contract:
#
# ```python
# # Canonical script for Day 10 grading by autograder (day10.py)
# def main():
#     # Hour 37
#     print("Class defined: Contact(name, phone)")
#     print("Object created: Ada / 5551234")
#     print("Display method: Ada -> 5551234")
#     print("Method call result: Ada is ready to contact.")
#     print("self reminder: self refers to the current object")
#
#     # Hour 38
#     print("Found contact: Grace -> 5552222")
#     print("Missing contact: None")
#     print("Search uses normalize: 'grace' matched 'Grace'")
#     print("Updated phone: Grace -> 5553333")
#     print("Object count: 3")
#
#     # Hour 39
#     print("Valid update accepted: True")
#     print("Stored phone after valid update: 5554444")
#     print("Invalid update accepted: False")
#     print("Stored phone after invalid update: 5554444")
#     print("Validation location: class methods keep business rules together")
#
#     # Hour 40
#     print("Checkpoint functions: add_contact, list_contacts, find_contact")
#     print("Checkpoint module plan: main.py handles menu, utils.py normalizes search")
#     print("Checkpoint class used: Contact")
#     print("Checkpoint features: add, list, search")
#     print("Checkpoint readiness: modular, readable, in-memory organizer")
#
# if __name__ == "__main__":
#     main()
# ```
