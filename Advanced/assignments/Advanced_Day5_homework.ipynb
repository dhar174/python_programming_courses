# %% [markdown]
# # Python Advanced - Day 5 Homework
#
# **Runbook alignment (Day 5, Hours 17-20):**
# - Hour 17: GUI fundamentals (Tkinter or ttk): event loop, widgets, callbacks
# - Hour 18: Layout and usability: grid, pack, spacing, resizing
# - Hour 19: Forms, validation, and user feedback patterns
# - Hour 20: Record list UI with Listbox or Treeview and selection events
#
# This homework begins the desktop interface for the tracker project with widgets, layout, validation, and record browsing.

# %% [markdown]
# ### Autograder Integration Requirements
#
# This assignment is graded automatically by the **Global Autograder**.
#
# - All solution code must live in this notebook and run without errors.
# - The autograder converts the submission notebook to `advanced_day5.py` and grades it against `criteria.json`.
# - Required outputs must exactly match the labeled canonical strings in `criteria.json`.
# - Keep output deterministic: no randomness, live timestamps, network calls, or hidden external state.
# - Do not rename this notebook or move the config files (`criteria.json`, `setup.json`, `feedback.json`).
# - Keep file access inside the assignment directory only.
# - Run all cells before submitting.

# %% [markdown]
# ## Part 1: Hour 17 - GUI fundamentals (Tkinter or ttk): event loop, widgets, callbacks
#
# **Goal:** Build a simple Tkinter window with one working action.
#
# **Best practice:** Create widgets clearly and wire callbacks to small handler functions.
#
# **Avoid this pitfall:** Burying business rules directly in callbacks makes the GUI brittle.

# %%
# Hour 17 starter
# Focus: GUI fundamentals (Tkinter or ttk): event loop, widgets, callbacks
# Goal: a simple Tkinter window with one working action
# Best practice: Create widgets clearly and wire callbacks to small handler functions.
# Pitfall to avoid: Burying business rules directly in callbacks makes the GUI brittle.
# TODO: Write your solution here.
# TODO: Print labeled lines that match the Hour 17 contract in criteria.json.

# %% [markdown]
# ### Practice and Review
#
# - Explain why this hour matters to the capstone.
# - Note how you would test or demo this hour's deliverable.
# - Compare your labels to the canonical contract before submission.

# %% [markdown]
# ## Part 2: Hour 18 - Layout and usability: grid, pack, spacing, resizing
#
# **Goal:** Build a form layout that stays readable when the window changes size.
#
# **Best practice:** Choose one layout strategy per container and test resizing early.
#
# **Avoid this pitfall:** Mixing pack and grid in the same container causes layout bugs.

# %%
# Hour 18 starter
# Focus: Layout and usability: grid, pack, spacing, resizing
# Goal: a form layout that stays readable when the window changes size
# Best practice: Choose one layout strategy per container and test resizing early.
# Pitfall to avoid: Mixing pack and grid in the same container causes layout bugs.
# TODO: Write your solution here.
# TODO: Print labeled lines that match the Hour 18 contract in criteria.json.

# %% [markdown]
# ### Practice and Review
#
# - Explain why this hour matters to the capstone.
# - Note how you would test or demo this hour's deliverable.
# - Compare your labels to the canonical contract before submission.

# %% [markdown]
# ## Part 3: Hour 19 - Forms, validation, and user feedback patterns
#
# **Goal:** Build a validated form that reports success and error states clearly.
#
# **Best practice:** Validate user input near the form boundary and show friendly feedback.
#
# **Avoid this pitfall:** Failing silently after bad input leaves users stuck.

# %%
# Hour 19 starter
# Focus: Forms, validation, and user feedback patterns
# Goal: a validated form that reports success and error states clearly
# Best practice: Validate user input near the form boundary and show friendly feedback.
# Pitfall to avoid: Failing silently after bad input leaves users stuck.
# TODO: Write your solution here.
# TODO: Print labeled lines that match the Hour 19 contract in criteria.json.

# %% [markdown]
# ### Practice and Review
#
# - Explain why this hour matters to the capstone.
# - Note how you would test or demo this hour's deliverable.
# - Compare your labels to the canonical contract before submission.

# %% [markdown]
# ## Part 4: Hour 20 - Record list UI with Listbox or Treeview and selection events
#
# **Goal:** Build a list-based record browser with reliable selection handling.
#
# **Best practice:** Bind selection events to stable record ids rather than row positions.
#
# **Avoid this pitfall:** Using display order as identity makes updates and deletes unsafe.

# %%
# Hour 20 starter
# Focus: Record list UI with Listbox or Treeview and selection events
# Goal: a list-based record browser with reliable selection handling
# Best practice: Bind selection events to stable record ids rather than row positions.
# Pitfall to avoid: Using display order as identity makes updates and deletes unsafe.
# TODO: Write your solution here.
# TODO: Print labeled lines that match the Hour 20 contract in criteria.json.

# %% [markdown]
# ### Practice and Review
#
# - Explain why this hour matters to the capstone.
# - Note how you would test or demo this hour's deliverable.
# - Compare your labels to the canonical contract before submission.

# %% [markdown]
# ## Reflection Questions
#
# 1. Which hour felt strongest today, and why?
# 2. Which output label was hardest to make deterministic?
# 3. What would you improve before a checkpoint or demo?
#
# ### Your Answers

# %% [markdown]
# ## Submission Checklist
#
# - My completed notebook stays named `Advanced_Day5_homework.ipynb`.
# - I copied a finished submission notebook into `submissions/` before grading.
# - My output labels match `criteria.json` exactly.
# - I avoided randomness, live timestamps, and hidden external state.
# - I ran all cells and fixed errors before submission.

# %%
# Final helper cell - write a canonical day script without notebook magics.
from pathlib import Path


def build_canonical_script() -> str:
    return """
def hour17_lines() -> list[str]:
    return [
        'Hour 17 | root window: tracker app',
        'Hour 17 | main widgets: label, entry, button',
        'Hour 17 | event loop: started',
        'Hour 17 | callback wired: add_task',
        'Hour 17 | gui rule: keep handlers thin',
    ]

def hour18_lines() -> list[str]:
    return [
        'Hour 18 | layout manager: grid',
        'Hour 18 | padding applied: 8',
        'Hour 18 | column stretch: enabled',
        'Hour 18 | resize behavior: stable',
        'Hour 18 | usability rule: align labels and inputs consistently',
    ]

def hour19_lines() -> list[str]:
    return [
        'Hour 19 | field read: title entry',
        'Hour 19 | blank title: rejected',
        'Hour 19 | status label: task added',
        'Hour 19 | invalid priority: warned',
        'Hour 19 | feedback rule: tell users what to fix',
    ]

def hour20_lines() -> list[str]:
    return [
        'Hour 20 | list widget: treeview',
        'Hour 20 | rows loaded: 3',
        'Hour 20 | selected id: task-002',
        'Hour 20 | detail panel: synced',
        'Hour 20 | selection rule: use stable record ids',
    ]

def main() -> None:
    for line in hour17_lines() + hour18_lines() + hour19_lines() + hour20_lines():
        print(line)


if __name__ == "__main__":
    main()
"""


if "__file__" not in globals():
    Path('day5.py').write_text(build_canonical_script(), encoding='utf-8')
