# %% [markdown]
# # Advanced Day 3 Filled Test Submission
#
# This sample submission matches the canonical autograder contract for local validation.

# %%
def main() -> None:
    print('Hour 9 | package root: tracker_app')
    print('Hour 9 | config module: settings.py')
    print('Hour 9 | import path: tracker_app.services.task_service')
    print('Hour 9 | env loaded: TRACKER_ENV=dev')
    print('Hour 9 | structure rule: keep app entrypoints thin')
    print('Hour 10 | logger name: tracker.service')
    print('Hour 10 | info: created task Pay rent')
    print('Hour 10 | warning: missing priority defaulted')
    print('Hour 10 | error: invalid payload rejected')
    print('Hour 10 | rule: log context without leaking secrets')
    print('Hour 11 | file mode: context manager used')
    print('Hour 11 | temp file written: yes')
    print('Hour 11 | temp file closed: yes')
    print('Hour 11 | json snapshot keys: tasks, saved_at')
    print('Hour 11 | safety rule: cleanup happens automatically')
    print('Hour 12 | timing decorator: add_task took 0.002s')
    print('Hour 12 | auth decorator: write action blocked')
    print('Hour 12 | validation decorator: blank title rejected')
    print('Hour 12 | wrapped result: task created')
    print('Hour 12 | decorator rule: keep wrappers small and focused')


if __name__ == "__main__":
    main()
