# %% [markdown]
# # Python Advanced - Day 1 Homework
#
# **Scope boundary for this assignment:** Session 1 (Hours 1-4) only.
#
# **Topics Covered (graded):**
# - Advanced kickoff, baseline diagnostic, and Git workflow
# - Designing classes from requirements
# - Properties, invariants, and custom exceptions
# - Composition vs inheritance with lightweight polymorphism
#
# **Instructions:**
# - Complete all **required graded** exercises in order.
# - Write your solutions in the provided code cells.
# - Prefer clear, modern Python: type hints, descriptive names, small methods, and f-strings.
# - Keep user interaction (`input()` / `print()`) out of your domain classes unless a prompt explicitly asks for UI code.
# - Run every required cell before submitting so you catch errors early.
#
# **Submission:**
# - Save your completed notebook with the canonical filename pattern that includes `Advanced_Day1`.
# - Make sure your work stays inside this assignment directory.
# - Submit according to your instructor's directions.
#
# ---
#
# ### 🤖 Autograder Integration
#
# This assignment is intended to be converted to **`advanced_day1.py`** during local grading for the Advanced Day 1 configuration.
#
# **Critical submission rules (read carefully):**
# - Do **not** rename this notebook file, move it to a different directory, or alter the config files (`criteria.json`, `setup.json`).
# - If your instructor asks you to stage a submission notebook, place it in `Advanced/assignments/Advanced_Day1_homework/submissions/`.
# - Your final outputs for required tasks must be deterministic. Do **not** depend on live timestamps, randomness, or external files outside this folder.
# - Keep output formatting stable: labels, capitalization, punctuation, and ordering matter when exact strings are checked.
# - Avoid notebook magics such as `%%writefile`; use standard Python only so `nbconvert` can turn your notebook into a script cleanly.
#
# If you are unsure whether a print line is required, compare your solution against the canonical output reference at the end of this notebook.

# %% [markdown]
# ---
# ## Part 1: Setup, Diagnostic Thinking, and Git Workflow (20 points)
#
# ### Exercise 1.1: Environment Summary (6 points)
# Create a short script that prints:
# - your name
# - one learning goal for the week
# - your Python version
#
# Use the `sys` module for the Python version. Use clear labels such as `Student:` and `Goal:`.
#
# ### Exercise 1.2: Project Scaffold Checklist (7 points)
# Print a one-line summary of the standard project folders for this course capstone: `src`, `tests`, `data`, and `reports`. Then print a second line that summarizes the Git workflow you expect to use during the course.
#
# ### Exercise 1.3: Baseline Diagnostic (7 points)
# Write a tiny diagnostic example that proves you can work with:
# - a class
# - a dictionary
# - exception handling
# - file-safe thinking (describe what you would save, but do not write outside this assignment directory)
#
# Your diagnostic output should finish with a clear readiness marker such as `Diagnostic status: ready`.

# %%
# Part 1 starter cell
import sys

# TODO: Replace the placeholder values with your own information.
student_name: str = "Your Name"
weekly_goal: str = "strengthen class design"

# TODO: Print the environment summary with clear labels.
# TODO: Print the project scaffold checklist line.
# TODO: Print the Git workflow line.
# TODO: Add a tiny diagnostic class + dictionary example and finish with a readiness marker.

# %% [markdown]
# ---
# ## Part 2: Designing Classes from Requirements (20 points)
#
# ### Exercise 2.1: Requirements to Responsibilities (10 points)
# Choose a small tracker domain such as tasks, contacts, inventory, notes, or expenses. Write 5-8 requirement bullets in comments or Markdown, then design **3-5 classes** that match those requirements.
#
# For each class, identify:
# - what it **knows** (attributes)
# - what it **does** (methods)
#
# ### Exercise 2.2: Boundaries and Behavior (10 points)
# Implement at least one domain class and one coordinating class (for example, a service or repository). Demonstrate a clean boundary:
# - the model protects its own state
# - the coordinating layer orchestrates work
# - UI concerns stay outside both
#
# Use a tiny demonstration block that creates an object and prints a summary from outside the class itself.

# %%
# Part 2 starter cell
from dataclasses import dataclass

# TODO: Write your requirement bullets as comments here.
# Example idea: a Task tracker with tasks, a repository, and a service layer.

@dataclass
class Task:
    task_id: str
    title: str
    priority: int = 2
    done: bool = False

    def mark_done(self) -> None:
        """Mark the task complete without printing UI messages here."""
        self.done = True


# TODO: Add a coordinating class such as TaskRepository or TaskService.
# TODO: Demonstrate the boundary rule from outside the model class.

# %% [markdown]
# ---
# ## Part 3: Properties, Invariants, and Custom Exceptions (20 points)
#
# ### Exercise 3.1: Protect an Invariant (10 points)
# Take one important attribute from your domain model and convert it into a validated property using `@property` and a setter.
#
# Examples:
# - title must not be blank
# - amount must be positive
# - priority must be an integer between 1 and 5
#
# ### Exercise 3.2: Domain Exceptions (10 points)
# Create at least two custom exceptions for your domain, such as `ValidationError` and `NotFoundError`.
#
# Then show:
# - one example where invalid data raises `ValidationError`
# - one example where looking up a missing record raises `NotFoundError`
#
# Catch the specific exceptions in a small driver block and print friendly messages there rather than inside the model.

# %%
# Part 3 starter cell
class ValidationError(Exception):
    """Raised when a domain rule is violated."""


class NotFoundError(Exception):
    """Raised when a requested record cannot be found."""


class Ticket:
    def __init__(self, ticket_id: str, title: str, priority: int = 2) -> None:
        self.ticket_id = ticket_id
        self.title = title
        self.priority = priority

    @property
    def priority(self) -> int:
        return self._priority

    @priority.setter
    def priority(self, value: int) -> None:
        # TODO: Replace this starter logic with your own validated rule(s).
        if not isinstance(value, int):
            raise ValidationError('priority must be an integer')
        self._priority = value


# TODO: Add at least one more invariant (for example, non-empty title).
# TODO: Demonstrate specific exception handling below.

# %% [markdown]
# ---
# ## Part 4: Composition vs Inheritance + Polymorphism (20 points)
#
# ### Exercise 4.1: Replace a Branchy Design (10 points)
# Start with a problem that might tempt you to write a large `if/elif` chain, such as exporting task data, sending notifications, or processing payments. Refactor it into **two or more classes** that share the same method name.
#
# ### Exercise 4.2: Show Composition Clearly (10 points)
# Create another class that **has a** collaborator object rather than inheriting from it. Demonstrate why composition is flexible by swapping the collaborator for a different implementation without changing the caller's code.
#
# Stretch idea: add a third implementation after the first two are working.

# %%
# Part 4 starter cell
class TextExporter:
    def export(self, task: Task) -> str:
        return f"{task.task_id} | {task.title}"


class DictExporter:
    def export(self, task: Task) -> dict[str, str]:
        return {"id": task.task_id, "title": task.title}


class TaskPresenter:
    def __init__(self, exporter) -> None:
        self.exporter = exporter

    def present(self, task: Task):
        return self.exporter.export(task)


# TODO: Add a second composition example such as a notifier or payment processor.
# TODO: Demonstrate that the caller can swap implementations without new if/elif branches.

# %% [markdown]
# ---
# ## Reflection and Submission Checklist
#
# Before submitting, verify:
# - [ ] All **required graded** cells run without errors
# - [ ] Domain classes avoid direct `input()` / `print()` for business logic
# - [ ] At least one invariant is enforced with a property or another clear validation mechanism
# - [ ] Custom exceptions are specific and handled intentionally
# - [ ] Composition and polymorphism examples remove unnecessary branching
# - [ ] Output lines used for grading are deterministic and consistently formatted
#
# **Required graded total: 80 points**
#
# ### Autograder checklist
# - [ ] Output labels match canonical strings in `criteria.json`
# - [ ] No extra whitespace or punctuation appears in required output lines
# - [ ] Exception messages stay stable enough for exact checks when requested
# - [ ] File paths remain inside this assignment directory

# %% [markdown]
# ---
# ## 🤖 Autograder Helper — Canonical Output Reference (Required Graded Tasks)
#
# Use the reference below to understand the kinds of canonical markers the local Advanced Day 1 configuration checks for. Keep your own solution authentic, but make sure equivalent required lines appear when your notebook is converted to `advanced_day1.py`.
#
# ```python
# # Canonical script for Advanced Day 1 grading by autograder (advanced_day1.py)
# def main():
#     print("Student: Jane Doe")
#     print("Goal: strengthen class design")
#     print("Python Version: 3.11.5")
#     print("Project folders: src, tests, data, reports")
#     print("Git workflow: clone -> pull -> status -> add -> commit -> push")
#     print("Diagnostic status: ready")
#
#     print("Domain classes: Task, TaskRepository, TaskService")
#     print("Boundary rule: service validates, model protects invariants")
#     print("Task summary: TASK-101 | Draft syllabus | priority=2 | done=False")
#
#     print("Priority set to: 3")
#     print("ValidationError: title cannot be empty")
#     print("NotFoundError: task 404 was not found")
#
#     print("Composed notifier sent: Task created")
#     print("Export text: TASK-101 | Draft syllabus")
#     print("Export dict: {'id': 'TASK-101', 'title': 'Draft syllabus'}")
#
# if __name__ == "__main__":
#     main()
# ```
