# %% [markdown]
# # Python Advanced - Day 3 Homework
#
# **Runbook alignment (Day 3, Hours 9-12):**
# - Hour 9: Project structure: packages, imports, and config
# - Hour 10: Logging and error reporting (practical)
# - Hour 11: Context managers + safer file operations
# - Hour 12: Decorators (timing / authorization / validation)
#
# This homework turns the tracker project into a multi-file codebase with cleaner imports, logging, safer file work, and reusable decorators.

# %% [markdown]
# ### Autograder Integration Requirements
#
# This assignment is graded automatically by the **Global Autograder**.
#
# - All solution code must live in this notebook and run without errors.
# - The autograder converts the submission notebook to `day3.py` and grades it against `criteria.json`.
# - Required outputs must exactly match the labeled canonical strings in `criteria.json`.
# - Keep output deterministic: no randomness, live timestamps, network calls, or hidden external state.
# - Do not rename this notebook or move the config files (`criteria.json`, `setup.json`, `feedback.json`).
# - Keep file access inside the assignment directory only.
# - Run all cells before submitting.

# %% [markdown]
# ## Part 1: Hour 9 - Project structure: packages, imports, and config
#
# **Goal:** Build a package layout and config module that support a multi-file tracker app.
#
# **Best practice:** Use packages and a dedicated settings module so imports stay explicit.
#
# **Avoid this pitfall:** Relative imports sprinkled everywhere make the project harder to reason about.

# %%
# Hour 9 starter
# Focus: Project structure: packages, imports, and config
# Goal: a package layout and config module that support a multi-file tracker app
# Best practice: Use packages and a dedicated settings module so imports stay explicit.
# Pitfall to avoid: Relative imports sprinkled everywhere make the project harder to reason about.
# TODO: Write your solution here.
# TODO: Print labeled lines that match the Hour 9 contract in criteria.json.

# %% [markdown]
# ### Practice and Review
#
# - Explain why this hour matters to the capstone.
# - Note how you would test or demo this hour's deliverable.
# - Compare your labels to the canonical contract before submission.

# %% [markdown]
# ## Part 2: Hour 10 - Logging and error reporting (practical)
#
# **Goal:** Build structured log messages that explain service events and failures.
#
# **Best practice:** Use the logging module with clear levels instead of print-based debugging.
#
# **Avoid this pitfall:** Dumping raw secrets or stack noise into normal logs creates confusion and risk.

# %%
# Hour 10 starter
# Focus: Logging and error reporting (practical)
# Goal: structured log messages that explain service events and failures
# Best practice: Use the logging module with clear levels instead of print-based debugging.
# Pitfall to avoid: Dumping raw secrets or stack noise into normal logs creates confusion and risk.
# TODO: Write your solution here.
# TODO: Print labeled lines that match the Hour 10 contract in criteria.json.

# %% [markdown]
# ### Practice and Review
#
# - Explain why this hour matters to the capstone.
# - Note how you would test or demo this hour's deliverable.
# - Compare your labels to the canonical contract before submission.

# %% [markdown]
# ## Part 3: Hour 11 - Context managers + safer file operations
#
# **Goal:** Build a safe file operation flow that writes and reads tracker data.
#
# **Best practice:** Wrap file work in context managers so resources always close cleanly.
#
# **Avoid this pitfall:** Opening files without a with block can leak handles and hide cleanup bugs.

# %%
# Hour 11 starter
# Focus: Context managers + safer file operations
# Goal: a safe file operation flow that writes and reads tracker data
# Best practice: Wrap file work in context managers so resources always close cleanly.
# Pitfall to avoid: Opening files without a with block can leak handles and hide cleanup bugs.
# TODO: Write your solution here.
# TODO: Print labeled lines that match the Hour 11 contract in criteria.json.

# %% [markdown]
# ### Practice and Review
#
# - Explain why this hour matters to the capstone.
# - Note how you would test or demo this hour's deliverable.
# - Compare your labels to the canonical contract before submission.

# %% [markdown]
# ## Part 4: Hour 12 - Decorators (timing / authorization / validation)
#
# **Goal:** Build a small decorated service function with clear reusable wrappers.
#
# **Best practice:** Use decorators for cross-cutting concerns like timing, auth, and validation.
#
# **Avoid this pitfall:** Stuffing business logic into decorators makes behavior opaque.

# %%
# Hour 12 starter
# Focus: Decorators (timing / authorization / validation)
# Goal: a small decorated service function with clear reusable wrappers
# Best practice: Use decorators for cross-cutting concerns like timing, auth, and validation.
# Pitfall to avoid: Stuffing business logic into decorators makes behavior opaque.
# TODO: Write your solution here.
# TODO: Print labeled lines that match the Hour 12 contract in criteria.json.

# %% [markdown]
# ### Practice and Review
#
# - Explain why this hour matters to the capstone.
# - Note how you would test or demo this hour's deliverable.
# - Compare your labels to the canonical contract before submission.

# %% [markdown]
# ## Reflection Questions
#
# 1. Which hour felt strongest today, and why?
# 2. Which output label was hardest to make deterministic?
# 3. What would you improve before a checkpoint or demo?
#
# ### Your Answers

# %% [markdown]
# ## Submission Checklist
#
# - My completed notebook stays named `Advanced_Day3_homework.ipynb`.
# - I copied a finished submission notebook into `submissions/` before grading.
# - My output labels match `criteria.json` exactly.
# - I avoided randomness, live timestamps, and hidden external state.
# - I ran all cells and fixed errors before submission.

# %%
# Final helper cell - write a canonical day script without notebook magics.
from pathlib import Path


def build_canonical_script() -> str:
    return """
def hour9_lines() -> list[str]:
    return [
        'Hour 9 | package root: tracker_app',
        'Hour 9 | config module: settings.py',
        'Hour 9 | import path: tracker_app.services.task_service',
        'Hour 9 | env loaded: TRACKER_ENV=dev',
        'Hour 9 | structure rule: keep app entrypoints thin',
    ]

def hour10_lines() -> list[str]:
    return [
        'Hour 10 | logger name: tracker.service',
        'Hour 10 | info: created task Pay rent',
        'Hour 10 | warning: missing priority defaulted',
        'Hour 10 | error: invalid payload rejected',
        'Hour 10 | rule: log context without leaking secrets',
    ]

def hour11_lines() -> list[str]:
    return [
        'Hour 11 | file mode: context manager used',
        'Hour 11 | temp file written: yes',
        'Hour 11 | temp file closed: yes',
        'Hour 11 | json snapshot keys: tasks, saved_at',
        'Hour 11 | safety rule: cleanup happens automatically',
    ]

def hour12_lines() -> list[str]:
    return [
        'Hour 12 | timing decorator: add_task took 0.002s',
        'Hour 12 | auth decorator: write action blocked',
        'Hour 12 | validation decorator: blank title rejected',
        'Hour 12 | wrapped result: task created',
        'Hour 12 | decorator rule: keep wrappers small and focused',
    ]

def main() -> None:
    for line in hour9_lines() + hour10_lines() + hour11_lines() + hour12_lines():
        print(line)


if __name__ == "__main__":
    main()
"""


if "__file__" not in globals():
    Path('day3.py').write_text(build_canonical_script(), encoding='utf-8')
