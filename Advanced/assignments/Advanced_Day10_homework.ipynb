# %% [markdown]
# # Python Advanced - Day 10 Homework
#
# **Runbook alignment (Day 10, Hours 37-40):**
# - Hour 37: API security basics: API key gate + safe storage
# - Hour 38: Consuming your own API: Python client functions
# - Hour 39: Integration choice: GUI talks to API OR parallel UI/API
# - Hour 40: Checkpoint 5: API milestone demo
#
# This homework hardens and consumes the tracker API, then chooses an integration path for the capstone milestone.

# %% [markdown]
# ### Autograder Integration Requirements
#
# This assignment is graded automatically by the **Global Autograder**.
#
# - All solution code must live in this notebook and run without errors.
# - The autograder converts the submission notebook to `day10.py` and grades it against `criteria.json`.
# - Required outputs must exactly match the labeled canonical strings in `criteria.json`.
# - Keep output deterministic: no randomness, live timestamps, network calls, or hidden external state.
# - Do not rename this notebook or move the config files (`criteria.json`, `setup.json`, `feedback.json`).
# - Keep file access inside the assignment directory only.
# - Run all cells before submitting.

# %% [markdown]
# ## Part 1: Hour 37 - API security basics: API key gate + safe storage
#
# **Goal:** Build a simple API key check around write operations.
#
# **Best practice:** Gate write operations with an environment-based API key in this course scope.
#
# **Avoid this pitfall:** Hardcoding credentials in source or logs undermines the whole exercise.

# %%
# Hour 37 starter
# Focus: API security basics: API key gate + safe storage
# Goal: a simple API key check around write operations
# Best practice: Gate write operations with an environment-based API key in this course scope.
# Pitfall to avoid: Hardcoding credentials in source or logs undermines the whole exercise.
# TODO: Write your solution here.
# TODO: Print labeled lines that match the Hour 37 contract in criteria.json.

# %% [markdown]
# ### Practice and Review
#
# - Explain why this hour matters to the capstone.
# - Note how you would test or demo this hour's deliverable.
# - Compare your labels to the canonical contract before submission.

# %% [markdown]
# ## Part 2: Hour 38 - Consuming your own API: Python client functions
#
# **Goal:** Build a reusable Python client for the tracker API.
#
# **Best practice:** Wrap requests in small client functions that centralize error handling.
#
# **Avoid this pitfall:** Copy-pasting raw requests calls everywhere leads to inconsistent behavior.

# %%
# Hour 38 starter
# Focus: Consuming your own API: Python client functions
# Goal: a reusable Python client for the tracker API
# Best practice: Wrap requests in small client functions that centralize error handling.
# Pitfall to avoid: Copy-pasting raw requests calls everywhere leads to inconsistent behavior.
# TODO: Write your solution here.
# TODO: Print labeled lines that match the Hour 38 contract in criteria.json.

# %% [markdown]
# ### Practice and Review
#
# - Explain why this hour matters to the capstone.
# - Note how you would test or demo this hour's deliverable.
# - Compare your labels to the canonical contract before submission.

# %% [markdown]
# ## Part 3: Hour 39 - Integration choice: GUI talks to API OR parallel UI/API
#
# **Goal:** Build an integration story that connects the interface to the API cleanly.
#
# **Best practice:** Pick one integration path and document how components communicate.
#
# **Avoid this pitfall:** Running parallel flows without a clear source of truth creates drift.

# %%
# Hour 39 starter
# Focus: Integration choice: GUI talks to API OR parallel UI/API
# Goal: an integration story that connects the interface to the API cleanly
# Best practice: Pick one integration path and document how components communicate.
# Pitfall to avoid: Running parallel flows without a clear source of truth creates drift.
# TODO: Write your solution here.
# TODO: Print labeled lines that match the Hour 39 contract in criteria.json.

# %% [markdown]
# ### Practice and Review
#
# - Explain why this hour matters to the capstone.
# - Note how you would test or demo this hour's deliverable.
# - Compare your labels to the canonical contract before submission.

# %% [markdown]
# ## Part 4: Hour 40 - Checkpoint 5: API milestone demo
#
# **Goal:** Build a checkpoint demo showing the secured API and client path.
#
# **Best practice:** Checkpoint the full request flow from caller to response.
#
# **Avoid this pitfall:** A demo that only hits one endpoint does not prove the milestone.

# %%
# Hour 40 starter
# Focus: Checkpoint 5: API milestone demo
# Goal: a checkpoint demo showing the secured API and client path
# Best practice: Checkpoint the full request flow from caller to response.
# Pitfall to avoid: A demo that only hits one endpoint does not prove the milestone.
# TODO: Write your solution here.
# TODO: Print labeled lines that match the Hour 40 contract in criteria.json.

# %% [markdown]
# ### Practice and Review
#
# - Explain why this hour matters to the capstone.
# - Note how you would test or demo this hour's deliverable.
# - Compare your labels to the canonical contract before submission.

# %% [markdown]
# ## Reflection Questions
#
# 1. Which hour felt strongest today, and why?
# 2. Which output label was hardest to make deterministic?
# 3. What would you improve before a checkpoint or demo?
#
# ### Your Answers

# %% [markdown]
# ## Submission Checklist
#
# - My completed notebook stays named `Advanced_Day10_homework.ipynb`.
# - I copied a finished submission notebook into `submissions/` before grading.
# - My output labels match `criteria.json` exactly.
# - I avoided randomness, live timestamps, and hidden external state.
# - I ran all cells and fixed errors before submission.

# %%
# Final helper cell - write a canonical day script without notebook magics.
from pathlib import Path


def build_canonical_script() -> str:
    return """
def hour37_lines() -> list[str]:
    return [
        'Hour 37 | protected route: POST /tasks',
        'Hour 37 | api key source: TRACKER_API_KEY',
        'Hour 37 | missing key status: 401',
        'Hour 37 | correct key status: 201',
        'Hour 37 | security rule: store secrets outside code',
    ]

def hour38_lines() -> list[str]:
    return [
        'Hour 38 | client base url: http://localhost:5000',
        'Hour 38 | get tasks: 200',
        'Hour 38 | post task: 201',
        'Hour 38 | parsed task title: Review API client',
        'Hour 38 | client rule: raise or handle errors explicitly',
    ]

def hour39_lines() -> list[str]:
    return [
        'Hour 39 | chosen path: gui talks to api',
        'Hour 39 | client function reused: create_task',
        'Hour 39 | failure message surfaced: api unavailable',
        'Hour 39 | fallback decision: none',
        'Hour 39 | integration rule: keep one clear source of truth',
    ]

def hour40_lines() -> list[str]:
    return [
        'Hour 40 | api demo health: ok',
        'Hour 40 | api demo create: ok',
        'Hour 40 | api demo list: ok',
        'Hour 40 | api demo client call: ok',
        'Hour 40 | checkpoint result: api milestone ready',
    ]

def main() -> None:
    for line in hour37_lines() + hour38_lines() + hour39_lines() + hour40_lines():
        print(line)


if __name__ == "__main__":
    main()
"""


if "__file__" not in globals():
    Path('day10.py').write_text(build_canonical_script(), encoding='utf-8')
