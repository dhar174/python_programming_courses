# %% [markdown]
# # Python Advanced - Day 6 Homework
#
# **Runbook alignment (Day 6, Hours 21-24):**
# - Hour 21: CRUD wiring in GUI: update and delete workflows
# - Hour 22: GUI architecture: controller separation + avoiding callback spaghetti
# - Hour 23: GUI mini-project sprint: persistence + polish
# - Hour 24: Checkpoint 3: GUI milestone demo
#
# This homework deepens the GUI by wiring CRUD flows, separating controller responsibilities, and preparing a polished checkpoint demo.

# %% [markdown]
# ### Autograder Integration Requirements
#
# This assignment is graded automatically by the **Global Autograder**.
#
# - All solution code must live in this notebook and run without errors.
# - The autograder converts the submission notebook to `day6.py` and grades it against `criteria.json`.
# - Required outputs must exactly match the labeled canonical strings in `criteria.json`.
# - Keep output deterministic: no randomness, live timestamps, network calls, or hidden external state.
# - Do not rename this notebook or move the config files (`criteria.json`, `setup.json`, `feedback.json`).
# - Keep file access inside the assignment directory only.
# - Run all cells before submitting.

# %% [markdown]
# ## Part 1: Hour 21 - CRUD wiring in GUI: update and delete workflows
#
# **Goal:** Build GUI update and delete flows that round-trip through application state.
#
# **Best practice:** Refresh the GUI from the current source of truth after each update or delete.
#
# **Avoid this pitfall:** Mutating stale widget state without reloading causes mismatched displays.

# %%
# Hour 21 starter
# Focus: CRUD wiring in GUI: update and delete workflows
# Goal: GUI update and delete flows that round-trip through application state
# Best practice: Refresh the GUI from the current source of truth after each update or delete.
# Pitfall to avoid: Mutating stale widget state without reloading causes mismatched displays.
# TODO: Write your solution here.
# TODO: Print labeled lines that match the Hour 21 contract in criteria.json.

# %% [markdown]
# ### Practice and Review
#
# - Explain why this hour matters to the capstone.
# - Note how you would test or demo this hour's deliverable.
# - Compare your labels to the canonical contract before submission.

# %% [markdown]
# ## Part 2: Hour 22 - GUI architecture: controller separation + avoiding callback spaghetti
#
# **Goal:** Build a controller-style GUI structure with clean responsibilities.
#
# **Best practice:** Keep controller methods thin and delegate business logic to services.
#
# **Avoid this pitfall:** Callback spaghetti grows when widget code and domain rules live in the same function.

# %%
# Hour 22 starter
# Focus: GUI architecture: controller separation + avoiding callback spaghetti
# Goal: a controller-style GUI structure with clean responsibilities
# Best practice: Keep controller methods thin and delegate business logic to services.
# Pitfall to avoid: Callback spaghetti grows when widget code and domain rules live in the same function.
# TODO: Write your solution here.
# TODO: Print labeled lines that match the Hour 22 contract in criteria.json.

# %% [markdown]
# ### Practice and Review
#
# - Explain why this hour matters to the capstone.
# - Note how you would test or demo this hour's deliverable.
# - Compare your labels to the canonical contract before submission.

# %% [markdown]
# ## Part 3: Hour 23 - GUI mini-project sprint: persistence + polish
#
# **Goal:** Build a small but demo-ready GUI mini project.
#
# **Best practice:** Use a short sprint to integrate persistence, feedback, and polish around one workflow.
#
# **Avoid this pitfall:** Polishing visuals before core save or load works wastes sprint time.

# %%
# Hour 23 starter
# Focus: GUI mini-project sprint: persistence + polish
# Goal: a small but demo-ready GUI mini project
# Best practice: Use a short sprint to integrate persistence, feedback, and polish around one workflow.
# Pitfall to avoid: Polishing visuals before core save or load works wastes sprint time.
# TODO: Write your solution here.
# TODO: Print labeled lines that match the Hour 23 contract in criteria.json.

# %% [markdown]
# ### Practice and Review
#
# - Explain why this hour matters to the capstone.
# - Note how you would test or demo this hour's deliverable.
# - Compare your labels to the canonical contract before submission.

# %% [markdown]
# ## Part 4: Hour 24 - Checkpoint 3: GUI milestone demo
#
# **Goal:** Build a checkpoint demo that proves the GUI can create, update, delete, and persist.
#
# **Best practice:** Checkpoint the full CRUD demo path, not isolated screenshots.
#
# **Avoid this pitfall:** A milestone is not complete if one core flow only works in a happy path.

# %%
# Hour 24 starter
# Focus: Checkpoint 3: GUI milestone demo
# Goal: a checkpoint demo that proves the GUI can create, update, delete, and persist
# Best practice: Checkpoint the full CRUD demo path, not isolated screenshots.
# Pitfall to avoid: A milestone is not complete if one core flow only works in a happy path.
# TODO: Write your solution here.
# TODO: Print labeled lines that match the Hour 24 contract in criteria.json.

# %% [markdown]
# ### Practice and Review
#
# - Explain why this hour matters to the capstone.
# - Note how you would test or demo this hour's deliverable.
# - Compare your labels to the canonical contract before submission.

# %% [markdown]
# ## Reflection Questions
#
# 1. Which hour felt strongest today, and why?
# 2. Which output label was hardest to make deterministic?
# 3. What would you improve before a checkpoint or demo?
#
# ### Your Answers

# %% [markdown]
# ## Submission Checklist
#
# - My completed notebook stays named `Advanced_Day6_homework.ipynb`.
# - I copied a finished submission notebook into `submissions/` before grading.
# - My output labels match `criteria.json` exactly.
# - I avoided randomness, live timestamps, and hidden external state.
# - I ran all cells and fixed errors before submission.

# %%
# Final helper cell - write a canonical day script without notebook magics.
from pathlib import Path


def build_canonical_script() -> str:
    return """
def hour21_lines() -> list[str]:
    return [
        'Hour 21 | selected id: task-002',
        'Hour 21 | update action: priority set to high',
        'Hour 21 | delete action: task-003 removed',
        'Hour 21 | list refresh: complete',
        'Hour 21 | crud rule: reload the view after state changes',
    ]

def hour22_lines() -> list[str]:
    return [
        'Hour 22 | ui class: TrackerApp',
        'Hour 22 | service call: delegated',
        'Hour 22 | widget lookup: local to ui',
        'Hour 22 | state field: current_selection_id',
        'Hour 22 | architecture rule: callbacks coordinate, services decide',
    ]

def hour23_lines() -> list[str]:
    return [
        'Hour 23 | persistence hook: save on demand',
        'Hour 23 | polish item: status banner added',
        'Hour 23 | validation sweep: passed',
        'Hour 23 | sample data: loaded',
        'Hour 23 | sprint result: demo flow ready',
    ]

def hour24_lines() -> list[str]:
    return [
        'Hour 24 | demo start: app opens cleanly',
        'Hour 24 | demo add: ok',
        'Hour 24 | demo update: ok',
        'Hour 24 | demo delete: ok',
        'Hour 24 | checkpoint result: gui milestone ready',
    ]

def main() -> None:
    for line in hour21_lines() + hour22_lines() + hour23_lines() + hour24_lines():
        print(line)


if __name__ == "__main__":
    main()
"""


if "__file__" not in globals():
    Path('day6.py').write_text(build_canonical_script(), encoding='utf-8')
