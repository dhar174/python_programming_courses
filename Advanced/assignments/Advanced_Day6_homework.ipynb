# %% [markdown]
# # Advanced Day 6 Homework\n\nComplete each task below using only concepts covered in class.\n

# %%
# TODO: Write your Day homework solution code here.\n
